# %%
import nbimporter
import helper_methods as hm
import preprocessing as pp
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, matthews_corrcoef
from sklearn.ensemble import RandomForestClassifier
# Out:
# Importing Jupyter notebook from helper_methods.ipynb
# Importing Jupyter notebook from preprocessing.ipynb

# %% [markdown]
# ### Random Forest Classifier Implementation

# %% [markdown]
# ### Finding Optimal Parameters

# %%
def print_parameters_accuracy(accuracies):
    print('#Features \t Estimators \t Accuracy')
    for i in range(len(accuracies)):
        print(accuracies[i][0], '\t\t', accuracies[i][1], '\t\t', accuracies[i][2])
    print()

# %%
def find_optimal_values(max_features, max_estimators, num_splits = 10, symbol_name = 'AAPL', use_implementation = True):
    accuracies = list()
    for num_features in range(1, max_features + 1, 1):
        print('Features:', num_features)
        
        X_train, X_test, Y_train, Y_test = hm.prepare_data(num_features, symbol_name, is_binary_ouput=True)
        X_train, X_test, Y_train, Y_test = X_train.values, X_test.values, Y_train.values, Y_test.values
        
        for n_estimators in range(100, max_estimators + 100, 100):
            print('Estimators ------------------------>', n_estimators)
            rf_tscv = RandomForestClassifier(n_estimators=n_estimators, n_jobs=-1)
            if use_implementation:
                neighbour_accuracy = hm.timeSeriesCV(X_train, Y_train, num_splits, rf_tscv, is_classification=True)
            else:
                neighbour_accuracy = hm.rolling_cross_validation(X_train, Y_train, num_splits, rf_tscv, is_classification=True)
            accuracies.append([num_features, n_estimators, neighbour_accuracy])
    
    print_parameters_accuracy(accuracies)
    
    # Sorting the accuracies
    accuracies.sort(reverse=True, key=lambda x: x[2])
    print_parameters_accuracy(accuracies)
    
    return accuracies[0][0], accuracies[0][1]

# %%
def get_data_ready(symbol_name):
    start_time = time.time()
    num_features, n_estimators = find_optimal_values(max_features=15, max_estimators=1100, num_splits=10, symbol_name = symbol_name)
    end_time = time.time()
    print('Time taken:', end_time - start_time)
    
    X_train, X_test, Y_train, Y_test = hm.prepare_data(num_features)
    X_train, X_test, Y_train, Y_test = X_train.values, X_test.values, Y_train.values, Y_test.values
    return X_train, X_test, Y_train, Y_test, n_estimators

# %% [markdown]
# ### 1. SkLearn RF Classifier

# %%
def sklearn_RF_forecast(X_train, X_test, Y_train, Y_test, n_estimators):
    print('SKLEARN INBUILT')
    clf = RandomForestClassifier(n_estimators=n_estimators, n_jobs=-1)
    clf.fit(X_train, Y_train)
    print('Accuracy score --', clf.score(X_test, Y_test), '\n')

# %% [markdown]
# ### 2. Predicting using Implementation

# %% [markdown]
# ### Running RF

# %%
def forecast(X_train, X_test, Y_train, Y_test, n_estimators):
    print('Number of estimators --', n_estimators)
    sklearn_RF_forecast(X_train, X_test, Y_train, Y_test, n_estimators)
    
# X_train, X_test, Y_train, Y_test = hm.prepare_data(2)
# X_train, X_test, Y_train, Y_test = X_train.values, X_test.values, Y_train.values, Y_test.values
# forecast(X_train, X_test, Y_train, Y_test)

# %%
def run_RF(symbol_name):
    X_train, X_test, Y_train, Y_test, n_estimators = get_data_ready(symbol_name)
    forecast(X_train, X_test, Y_train, Y_test, n_estimators)

# %%
run_RF(symbol_name = 'INX')
# Out:
# Features: 1
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.4997165532879818
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.4994331065759636
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.49943310657596374
#
# Features: 2
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5034013605442177
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5076530612244897
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5053854875283447
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5073696145124718
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5107709750566893
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5073696145124716
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5079365079365078
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5093537414965986
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5119047619047619
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# Features: 3
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922902
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5008503401360545
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5093537414965986
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5014172335600907
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5011337868480725
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5025510204081632
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5017006802721089
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.503968253968254
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.4968820861678005
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5017006802721089
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5056689342403629
#
# Features: 4
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5022675736961452
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5042517006802721
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5014172335600907
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5002834467120182
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5005668934240363
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.503968253968254
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5053854875283447
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5034013605442177
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5068027210884354
#
# Features: 5
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5136054421768708
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5076530612244897
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5147392290249433
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5147392290249433
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5087868480725624
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.510204081632653
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5099206349206349
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5087868480725625
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5150226757369614
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5136054421768708
#
# Features: 6
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5014172335600907
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004535
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5028344671201814
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5028344671201813
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5079365079365079
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5056689342403629
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.4965986394557823
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922903
#
# Features: 7
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.501984126984127
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5076530612244897
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.51218820861678
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5093537414965987
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5079365079365079
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5116213151927437
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5170068027210885
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5133219954648527
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5110544217687074
#
# Features: 8
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5177607274793976
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5100880932082978
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5183290707587384
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5089514066496164
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5134981528843422
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5103722648479683
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5154873543620346
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5115089514066496
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5180448991190679
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5109406081273088
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5149190110826939
#
# Features: 9
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.51179312304632
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5245808468314862
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5197499289570902
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5152031827223643
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5191815856777494
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5157715260017051
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5166240409207162
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.522023302074453
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.525149190110827
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5197499289570902
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5194657573174197
#
# Features: 10
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5061096902529126
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5140664961636828
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5191815856777494
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.525149190110827
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5217391304347826
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5200341005967605
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5225916453537937
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5234441602728048
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5220233020744529
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5274225632281898
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5257175333901677
#
# Features: 11
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5174765558397272
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5103722648479682
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.525149190110827
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5183290707587384
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.515771526001705
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5149190110826941
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5225916453537937
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5225916453537937
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5171923842000568
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5140664961636829
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5240125035521455
#
# Features: 12
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5228758169934641
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5223074737141232
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5186132423984087
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5197499289570902
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5154873543620346
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5123614663256606
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5188974140380789
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5203182722364308
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5203182722364308
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5191815856777494
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5177607274793976
#
# Features: 13
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5140664961636829
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5154873543620346
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5149190110826939
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5157715260017051
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5166240409207161
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5137823245240125
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5200341005967605
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5211707871554419
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5225916453537937
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5160556976413754
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.512645637965331
#
# Features: 14
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.51179312304632
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5106564364876386
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5120772946859904
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5163398692810457
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5041204887752202
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5109406081273088
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5103722648479683
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5132139812446719
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5083830633702756
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5126456379653311
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5188974140380789
#
# Features: 15
# Estimators ------------------------> 100
# Implemented Rolling Cross Validation
# Accuracy: 0.5072463768115942
#
# Estimators ------------------------> 200
# Implemented Rolling Cross Validation
# Accuracy: 0.5069622051719238
#
# Estimators ------------------------> 300
# Implemented Rolling Cross Validation
# Accuracy: 0.5129298096050015
#
# Estimators ------------------------> 400
# Implemented Rolling Cross Validation
# Accuracy: 0.5120772946859904
#
# Estimators ------------------------> 500
# Implemented Rolling Cross Validation
# Accuracy: 0.5052571753339018
#
# Estimators ------------------------> 600
# Implemented Rolling Cross Validation
# Accuracy: 0.5152031827223643
#
# Estimators ------------------------> 700
# Implemented Rolling Cross Validation
# Accuracy: 0.5134981528843422
#
# Estimators ------------------------> 800
# Implemented Rolling Cross Validation
# Accuracy: 0.5072463768115942
#
# Estimators ------------------------> 900
# Implemented Rolling Cross Validation
# Accuracy: 0.5061096902529127
#
# Estimators ------------------------> 1000
# Implemented Rolling Cross Validation
# Accuracy: 0.5115089514066496
#
# Estimators ------------------------> 1100
# Implemented Rolling Cross Validation
# Accuracy: 0.5112247797669792
#
# #Features 	 Estimators 	 Accuracy
# 1 		 100 		 0.4997165532879818
# 1 		 200 		 0.4994331065759636
# 1 		 300 		 0.49943310657596374
# 1 		 400 		 0.49943310657596374
# 1 		 500 		 0.49943310657596374
# 1 		 600 		 0.49943310657596374
# 1 		 700 		 0.49943310657596374
# 1 		 800 		 0.49943310657596374
# 1 		 900 		 0.49943310657596374
# 1 		 1000 		 0.49943310657596374
# 1 		 1100 		 0.49943310657596374
# 2 		 100 		 0.5034013605442177
# 2 		 200 		 0.5059523809523809
# 2 		 300 		 0.5076530612244897
# 2 		 400 		 0.5053854875283447
# 2 		 500 		 0.5073696145124718
# 2 		 600 		 0.5107709750566893
# 2 		 700 		 0.5073696145124716
# 2 		 800 		 0.5079365079365078
# 2 		 900 		 0.5093537414965986
# 2 		 1000 		 0.5119047619047619
# 2 		 1100 		 0.5070861678004536
# 3 		 100 		 0.5045351473922902
# 3 		 200 		 0.5008503401360545
# 3 		 300 		 0.5093537414965986
# 3 		 400 		 0.5014172335600907
# 3 		 500 		 0.5011337868480725
