# %%
import nbimporter
import stats_helper as sh
import preprocessing as pp

import time
import math
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, accuracy_score, confusion_matrix, cohen_kappa_score
# Out:
# Importing Jupyter notebook from stats_helper.ipynb
# Importing Jupyter notebook from preprocessing.ipynb

# %% [markdown]
# Kohen Cappa - Kappa or Cohen’s Kappa is like classification accuracy, except that it is normalized at the baseline of random chance on your dataset. It is a more useful measure to use on problems that have an imbalance in the classes (e.g. 70-30 split for classes 0 and 1 and you can achieve 70% accuracy by predicting all instances are for class 0)
# https://machinelearningmastery.com/machine-learning-evaluation-metrics-in-r/
#
# The kappa statistic, which is a number between -1 and 1. The maximum value means complete agreement; zero or lower means chance agreement.

# %% [markdown]
# # Double Exponential Smoothing - Holt's Method

# %%
class Holt:
    """
        data - dataset with timestamps
        alpha - float [0.0, 1.0], smoothing parameter
        beta - float [0.0, 1.0], smoothing parameter for trend
    """
    
    def __init__(self, alpha, beta):
        self.alpha = alpha
        self.beta = beta
        self.result = []
    
    def fit(self, data_train):
        self.data_train = data_train
        
        # First value is same as series
        self.result.append(data_train[0])
        for n in range(1, len(data_train) + 1):
            
            # Initialising level and trend
            if n == 1:
                level, trend = data_train[0], data_train[1] - data_train[0]
            
            # Forecasting the point ahead
            if n >= len(data_train): 
                value = self.result[-1]
            else:
                value = data_train[n]
            
            last_level, level = level, self.alpha*value + (1 - self.alpha)*(level + trend)
            trend = self.beta*(level - last_level) + (1 - self.beta)*trend
            self.result.append(level + trend)

        # Returning the smoothed values (without the forecast)
        return self.result[:-1]
    
    # Returns the forecasted point during the fit
    def predict_one(self):
        return self.result[-1]

    def predict(self, data_test, is_classification):
        predictions = []
        self.result.append(self.data_train[0])
        for n in range(1, len(self.data_train) + len(data_test)):
            if n == 1:
                level, trend = self.data_train[0], self.data_train[1] - self.data_train[0]
            if n >= len(self.data_train): # we are forecasting
                value = data_test[n - len(self.data_train)]
                
                predict_value = self.result[-1]
                
                # Adding it for generating binary returns
                if n == len(self.data_train) and is_classification:
                    predictions.append(predict_value)
                
                predict_last_level, predict_level = level, self.alpha*predict_value + (1 - self.alpha)*(level + trend)
                predict_trend = self.beta*(predict_level - predict_last_level) + (1 - self.beta)*trend
                predictions.append(predict_level + predict_trend)
            else:
                value = self.data_train[n]
                
            last_level, level = level, self.alpha*value + (1 - self.alpha)*(level + trend)
            trend = self.beta*(level - last_level) + (1 - self.beta)*trend
            self.result.append(level + trend)
        
        if is_classification:
            return sh.output_to_binary_indicators(sh.data_daily_returns(predictions))
        
        return predictions

# %% [markdown]
# ## Plotting Holt

# %%
def plotDoubleExponentialSmoothing(data, alphas, betas):
    """
        Plots double exponential smoothing with different alphas and betas
        
        data - dataset with timestamps
        alphas - list of floats, smoothing parameters for level
        betas - list of floats, smoothing parameters for trend
    """
    
    with plt.style.context('seaborn-white'):    
        plt.figure(figsize=(20, 8))
        for alpha in alphas:
            for beta in betas:
                holt = Holt(alpha, beta)
                plt.plot(holt.fit(data), label="Alpha {}, beta {}".format(alpha, beta))
        plt.plot(data, label = "Actual")
        plt.legend(loc="best")
        plt.axis('tight')
        plt.title("Double Exponential Smoothing - Holt")
        plt.grid(True)
        
# plotDoubleExponentialSmoothing(values, alphas=[0.8, 0.05], betas=[0.8, 0.05])

# %%
def plotHolt(data, fit_data):
    plt.figure(figsize=(20, 7))
    plt.plot(range(len(data)), data, 'bo-')
    plt.plot(range(len(fit_data)), fit_data, 'r^--')
    plt.show()

# %% [markdown]
# ## Finding optimal parameters

# %%
def print_metric_values(metric_values):
    print('Alpha \t\t\t Beta \t\t\t Metric')
    for i in range(5): #range(len(metric_values)):
        print(metric_values[i][0], '\t\t\t', metric_values[i][1], '\t\t\t', metric_values[i][2])
    print()

# %%
def find_optimal_parameters(data_train, num_splits, alphas, betas, is_classification):
    metric_values = list()
    if is_classification:
        print('Using Accuracy for CV')
    else:
        print('Using Mean Squared Error for CV')
        
    for alpha in alphas:
        for beta in betas:
#             print("Alpha {}, Beta {}".format(alpha, beta))
            holt = Holt(alpha, beta)
            metric_value = sh.statTimeSeriesCV(data_train, num_splits, holt, is_classification)
            metric_values.append([alpha, beta, metric_value])
    
#     print_metric_values(metric_values)
    
    # Sorting the Metric Values
    metric_values.sort(reverse=True, key=lambda x: x[len(metric_values) - 1])
    print_metric_values(metric_values)
    
    return metric_values[0][0], metric_values[0][1]

# %% [markdown]
# ### RMS

# %%
# # Alpha:  0.99 			 Beta:  0.0 			 RMS:  1.778531300846033
# train_data, test_data = series_split(values)
# min_rms = 1000
# min_alpha = 0
# min_beta = 0
# for alpha in np.arange(0.0, 1.0, 0.01):
#     for beta in np.arange(0.0, 1.0, 0.01):
#         holt = Holt(alpha, beta)
#         updated = holt.predict_and_update(series_train=train_data, series_test=test_data)
#         rms = math.sqrt(mean_squared_error(test_data, updated))
#         if rms < min_rms:
#             min_rms = rms
#             min_alpha = alpha
#             min_beta = beta
# print('Alpha: ', min_alpha, '\t\t\t Beta: ', min_beta, '\t\t\t RMS: ', min_rms)

# %% [markdown]
# ### Returns and Accuracy Score

# %%
# ## Alpha:  0.14 		 Beta:  0.86 		 acc:  0.5362872421695951
# train_data, test_data = series_split(values)
# bin_test_data = output_to_binary_indicators(data_daily_returns(train_data[-1:] + test_data))
# max_acc = 0
# max_alpha = 0
# max_beta = 0
# for alpha in np.arange(0.01, 1.0, 0.01):
#     for beta in np.arange(0.0, 1.0, 0.01):
#         holt = Holt(alpha, beta)
#         predictions = holt.predict_and_update(train_data, test_data[:])
#         acc = accuracy_score(bin_test_data, predictions)
#         if acc > max_acc:
#             max_acc = acc
#             max_alpha = alpha
#             max_beta = beta
# print('Alpha: ', max_alpha, '\t\t Beta: ', max_beta, '\t\t acc: ', max_acc)

# %% [markdown]
# ## Error Metric Values

# %% [markdown]
# ### Regression Metrics

# %% [markdown]
# ### Classification Metrics

# %% [markdown]
# ## Using Holt for Prediction

# %%
def forecast(data_train, data_test, alpha, beta, is_classification):
    print('Alpha: ', alpha, '\t Beta: ', beta)
    
    holt = Holt(alpha, beta)
    print('Fitting...')
    holt.fit(data_train)
    
    print('Predicting...') 
    predictions = holt.predict(data_test, is_classification)
    
    if is_classification:
        bin_data_test = sh.output_to_binary_indicators(sh.data_daily_returns(data_train[-1:] + data_test))
        sh.classification_metrics(bin_data_test, predictions)
    else:
        sh.regression_metrics(data_test, predictions)

# %%
def get_data_ready(symbol_name, alphas, betas, is_classification):
    start_time = time.time()
    num_splits = 10
    data_train, data_test = sh.prepare_data(symbol_name, train_ratio = 0.8)
    alpha, beta = find_optimal_parameters(data_train, num_splits, alphas, betas, is_classification)
    end_time = time.time()
    
    print('Time taken for Cross Validation:', end_time - start_time)
    return data_train, data_test, alpha, beta

# %%
def run_Holt(symbol_name):
    is_classification = False
    alphas = np.arange(0, 1, 0.01)
    betas = np.arange(0, 1, 0.01)
    
    data_train, data_test, alpha, beta = get_data_ready(symbol_name, alphas, betas, is_classification)
    forecast(data_train, data_test, alpha, beta, is_classification = True)

# %%
run_Holt(symbol_name = 'AAPL')
# Out:
# Using Mean Squared Error for CV
# Alpha 0.0, Beta 0.0
# Mean Metric Value:  49.38339575671656
#
# Alpha 0.0, Beta 0.01
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.02
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.03
# Mean Metric Value:  49.38339575671656
#
# Alpha 0.0, Beta 0.04
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.05
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.06
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.07
# Mean Metric Value:  49.38339575671656
#
# Alpha 0.0, Beta 0.08
# Mean Metric Value:  49.38339575671946
#
# Alpha 0.0, Beta 0.09
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.1
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.11
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.12
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.13
# Mean Metric Value:  49.38339575671846
#
# Alpha 0.0, Beta 0.14
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.15
# Mean Metric Value:  49.383395756713874
#
# Alpha 0.0, Beta 0.16
# Mean Metric Value:  49.383395756713604
#
# Alpha 0.0, Beta 0.17
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.18
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.19
# Mean Metric Value:  49.38339575671846
#
# Alpha 0.0, Beta 0.2
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.21
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.22
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.23
# Mean Metric Value:  49.38339575671946
#
# Alpha 0.0, Beta 0.24
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.25
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.26
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.27
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.28
# Mean Metric Value:  49.38339575671846
#
# Alpha 0.0, Beta 0.29
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.3
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.31
# Mean Metric Value:  49.38339575671658
#
# Alpha 0.0, Beta 0.32
# Mean Metric Value:  49.38339575671656
#
# Alpha 0.0, Beta 0.33
# Mean Metric Value:  49.38339575671628
#
# Alpha 0.0, Beta 0.34
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.35000000000000003
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.36
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.37
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.38
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.39
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.4
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.41000000000000003
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.42
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.43
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.44
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.45
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.46
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.47000000000000003
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.48
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.49
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.5
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.51
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.52
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.53
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.54
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.55
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.56
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.5700000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.58
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.59
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.6
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.61
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.62
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.63
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.64
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.65
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.66
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.67
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.68
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.6900000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.7000000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.71
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.72
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.73
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.74
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.75
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.76
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.77
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.78
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.79
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.8
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.81
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.8200000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.8300000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.84
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.85
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.86
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.87
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.88
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.89
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.9
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.91
# Mean Metric Value:  49.383395756713895
#
# Alpha 0.0, Beta 0.92
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.93
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.9400000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.9500000000000001
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.96
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.97
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.98
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.0, Beta 0.99
# Mean Metric Value:  49.38339575671758
#
# Alpha 0.01, Beta 0.0
# Mean Metric Value:  4.590616604693149
#
# Alpha 0.01, Beta 0.01
# Mean Metric Value:  3.626191848322464
#
# Alpha 0.01, Beta 0.02
# Mean Metric Value:  3.5524600702653806
#
# Alpha 0.01, Beta 0.03
# Mean Metric Value:  3.4390059420581065
#
# Alpha 0.01, Beta 0.04
# Mean Metric Value:  3.278593038838121
#
# Alpha 0.01, Beta 0.05
# Mean Metric Value:  3.1299490883736674
#
# Alpha 0.01, Beta 0.06
# Mean Metric Value:  3.047858687610491
#
# Alpha 0.01, Beta 0.07
# Mean Metric Value:  3.0103917752499747
#
# Alpha 0.01, Beta 0.08
# Mean Metric Value:  2.9860171488866207
#
# Alpha 0.01, Beta 0.09
# Mean Metric Value:  2.9515287031268618
#
# Alpha 0.01, Beta 0.1
# Mean Metric Value:  2.911611129404618
#
# Alpha 0.01, Beta 0.11
# Mean Metric Value:  2.8982022131776497
#
# Alpha 0.01, Beta 0.12
# Mean Metric Value:  2.936060649884036
#
# Alpha 0.01, Beta 0.13
# Mean Metric Value:  3.02860943007779
#
# Alpha 0.01, Beta 0.14
# Mean Metric Value:  3.163722248447478
#
# Alpha 0.01, Beta 0.15
# Mean Metric Value:  3.3167399891938203
#
# Alpha 0.01, Beta 0.16
# Mean Metric Value:  3.453806336998819
#
# Alpha 0.01, Beta 0.17
# Mean Metric Value:  3.546340097517138
#
# Alpha 0.01, Beta 0.18
# Mean Metric Value:  3.5868279303289747
#
# Alpha 0.01, Beta 0.19
# Mean Metric Value:  3.5879054555546457
#
# Alpha 0.01, Beta 0.2
# Mean Metric Value:  3.5678163992859404
#
# Alpha 0.01, Beta 0.21
# Mean Metric Value:  3.540034760211872
#
# Alpha 0.01, Beta 0.22
# Mean Metric Value:  3.513036618215045
#
# Alpha 0.01, Beta 0.23
# Mean Metric Value:  3.4929241903660446
#
# Alpha 0.01, Beta 0.24
# Mean Metric Value:  3.4833041057513845
#
# Alpha 0.01, Beta 0.25
# Mean Metric Value:  3.482639343643283
#
# Alpha 0.01, Beta 0.26
# Mean Metric Value:  3.48298991609052
#
# Alpha 0.01, Beta 0.27
# Mean Metric Value:  3.4733715206076297
#
# Alpha 0.01, Beta 0.28
# Mean Metric Value:  3.4455923254801837
#
# Alpha 0.01, Beta 0.29
# Mean Metric Value:  3.3980101210796168
#
# Alpha 0.01, Beta 0.3
# Mean Metric Value:  3.3350935737104046
#
# Alpha 0.01, Beta 0.31
# Mean Metric Value:  3.264156474411695
#
# Alpha 0.01, Beta 0.32
# Mean Metric Value:  3.191999243256733
#
# Alpha 0.01, Beta 0.33
# Mean Metric Value:  3.1232550856073336
#
# Alpha 0.01, Beta 0.34
# Mean Metric Value:  3.0606044204012477
#
# Alpha 0.01, Beta 0.35000000000000003
# Mean Metric Value:  3.0056869520573732
#
# Alpha 0.01, Beta 0.36
# Mean Metric Value:  2.9594288587414246
#
# Alpha 0.01, Beta 0.37
# Mean Metric Value:  2.921622531516099
#
# Alpha 0.01, Beta 0.38
# Mean Metric Value:  2.890712768765529
#
# Alpha 0.01, Beta 0.39
# Mean Metric Value:  2.8645714603672205
#
# Alpha 0.01, Beta 0.4
# Mean Metric Value:  2.8418150032401055
#
# Alpha 0.01, Beta 0.41000000000000003
# Mean Metric Value:  2.8225341100648285
#
# Alpha 0.01, Beta 0.42
# Mean Metric Value:  2.8078955912089505
#
# Alpha 0.01, Beta 0.43
# Mean Metric Value:  2.7989847988980734
#
# Alpha 0.01, Beta 0.44
# Mean Metric Value:  2.7956378412315006
#
# Alpha 0.01, Beta 0.45
# Mean Metric Value:  2.795932328329267
#
# Alpha 0.01, Beta 0.46
# Mean Metric Value:  2.796609350830859
#
# Alpha 0.01, Beta 0.47000000000000003
# Mean Metric Value:  2.7941781055537342
#
# Alpha 0.01, Beta 0.48
# Mean Metric Value:  2.7860961633027923
#
# Alpha 0.01, Beta 0.49
# Mean Metric Value:  2.7714577075439197
#
# Alpha 0.01, Beta 0.5
# Mean Metric Value:  2.7510318085856262
#
# Alpha 0.01, Beta 0.51
# Mean Metric Value:  2.726818824370498
#
# Alpha 0.01, Beta 0.52
# Mean Metric Value:  2.701337882881247
#
# Alpha 0.01, Beta 0.53
# Mean Metric Value:  2.6768523439461167
#
# Alpha 0.01, Beta 0.54
# Mean Metric Value:  2.654809697197508
#
# Alpha 0.01, Beta 0.55
# Mean Metric Value:  2.6357369236210935
#
# Alpha 0.01, Beta 0.56
# Mean Metric Value:  2.619568250711534
#
# Alpha 0.01, Beta 0.5700000000000001
# Mean Metric Value:  2.6060940292154395
#
# Alpha 0.01, Beta 0.58
# Mean Metric Value:  2.5951999830517387
#
# Alpha 0.01, Beta 0.59
# Mean Metric Value:  2.5868169284340428
#
# Alpha 0.01, Beta 0.6
# Mean Metric Value:  2.580748340179782
#
# Alpha 0.01, Beta 0.61
# Mean Metric Value:  2.5766058800871647
#
# Alpha 0.01, Beta 0.62
# Mean Metric Value:  2.5739554116615
#
# Alpha 0.01, Beta 0.63
# Mean Metric Value:  2.5725668043226038
#
# Alpha 0.01, Beta 0.64
# Mean Metric Value:  2.5725709908270122
#
# Alpha 0.01, Beta 0.65
# Mean Metric Value:  2.5744190269479907
#
# Alpha 0.01, Beta 0.66
# Mean Metric Value:  2.578677245702268
#
# Alpha 0.01, Beta 0.67
# Mean Metric Value:  2.585763674150284
#
# Alpha 0.01, Beta 0.68
# Mean Metric Value:  2.595733969271135
#
# Alpha 0.01, Beta 0.6900000000000001
# Mean Metric Value:  2.6081986728748703
#
# Alpha 0.01, Beta 0.7000000000000001
# Mean Metric Value:  2.622406529263959
#
# Alpha 0.01, Beta 0.71
# Mean Metric Value:  2.637456671277586
#
# Alpha 0.01, Beta 0.72
# Mean Metric Value:  2.652529382071227
#
# Alpha 0.01, Beta 0.73
# Mean Metric Value:  2.6670057514521424
#
# Alpha 0.01, Beta 0.74
# Mean Metric Value:  2.6804143955635014
#
# Alpha 0.01, Beta 0.75
# Mean Metric Value:  2.6922550793922904
#
# Alpha 0.01, Beta 0.76
# Mean Metric Value:  2.7018179072737403
#
# Alpha 0.01, Beta 0.77
# Mean Metric Value:  2.7081099736415655
#
# Alpha 0.01, Beta 0.78
# Mean Metric Value:  2.7099500253389057
#
# Alpha 0.01, Beta 0.79
# Mean Metric Value:  2.7062203409267065
#
# Alpha 0.01, Beta 0.8
# Mean Metric Value:  2.6961887884770084
#
# Alpha 0.01, Beta 0.81
# Mean Metric Value:  2.6797740271119714
#
# Alpha 0.01, Beta 0.8200000000000001
# Mean Metric Value:  2.657655832239577
#
# Alpha 0.01, Beta 0.8300000000000001
# Mean Metric Value:  2.6312071226320097
#
# Alpha 0.01, Beta 0.84
# Mean Metric Value:  2.6022903134289153
#
# Alpha 0.01, Beta 0.85
# Mean Metric Value:  2.5729882121061043
#
# Alpha 0.01, Beta 0.86
# Mean Metric Value:  2.5453366439658756
#
# Alpha 0.01, Beta 0.87
# Mean Metric Value:  2.521111311178493
#
# Alpha 0.01, Beta 0.88
# Mean Metric Value:  2.5017019929470337
#
# Alpha 0.01, Beta 0.89
# Mean Metric Value:  2.488082015415492
#
# Alpha 0.01, Beta 0.9
# Mean Metric Value:  2.480854903375366
#
# Alpha 0.01, Beta 0.91
# Mean Metric Value:  2.480343877142029
#
# Alpha 0.01, Beta 0.92
# Mean Metric Value:  2.4866881825121734
#
# Alpha 0.01, Beta 0.93
# Mean Metric Value:  2.4999183924180115
#
# Alpha 0.01, Beta 0.9400000000000001
# Mean Metric Value:  2.519994300800403
#
# Alpha 0.01, Beta 0.9500000000000001
# Mean Metric Value:  2.5468019549828913
#
# Alpha 0.01, Beta 0.96
# Mean Metric Value:  2.5801202912131576
#
# Alpha 0.01, Beta 0.97
# Mean Metric Value:  2.6195780577588175
#
# Alpha 0.01, Beta 0.98
# Mean Metric Value:  2.664621915282906
#
# Alpha 0.01, Beta 0.99
# Mean Metric Value:  2.714507760045647
#
# Alpha 0.02, Beta 0.0
# Mean Metric Value:  2.981618702302991
#
# Alpha 0.02, Beta 0.01
# Mean Metric Value:  2.4481970690110817
#
# Alpha 0.02, Beta 0.02
# Mean Metric Value:  2.349000545977947
#
# Alpha 0.02, Beta 0.03
# Mean Metric Value:  2.277176407337039
#
# Alpha 0.02, Beta 0.04
# Mean Metric Value:  2.239651024918314
#
# Alpha 0.02, Beta 0.05
# Mean Metric Value:  2.2288931864583623
#
# Alpha 0.02, Beta 0.06
# Mean Metric Value:  2.246157475246948
#
# Alpha 0.02, Beta 0.07
# Mean Metric Value:  2.28880757110122
#
# Alpha 0.02, Beta 0.08
# Mean Metric Value:  2.3382953293914195
#
# Alpha 0.02, Beta 0.09
# Mean Metric Value:  2.37315728994953
#
# Alpha 0.02, Beta 0.1
# Mean Metric Value:  2.3847140963947506
#
# Alpha 0.02, Beta 0.11
# Mean Metric Value:  2.377590518019156
#
# Alpha 0.02, Beta 0.12
# Mean Metric Value:  2.3606297539888788
#
# Alpha 0.02, Beta 0.13
# Mean Metric Value:  2.3394753558890464
#
# Alpha 0.02, Beta 0.14
# Mean Metric Value:  2.3145286402343572
#
# Alpha 0.02, Beta 0.15
# Mean Metric Value:  2.284038657981331
#
# Alpha 0.02, Beta 0.16
# Mean Metric Value:  2.2481486043603396
#
# Alpha 0.02, Beta 0.17
# Mean Metric Value:  2.2095920925584993
#
# Alpha 0.02, Beta 0.18
# Mean Metric Value:  2.1718933568051444
#
# Alpha 0.02, Beta 0.19
# Mean Metric Value:  2.137736255623497
#
# Alpha 0.02, Beta 0.2
# Mean Metric Value:  2.108424900472858
#
# Alpha 0.02, Beta 0.21
# Mean Metric Value:  2.0840554855009783
#
# Alpha 0.02, Beta 0.22
# Mean Metric Value:  2.063850490878377
#
# Alpha 0.02, Beta 0.23
# Mean Metric Value:  2.0465124281869387
#
# Alpha 0.02, Beta 0.24
# Mean Metric Value:  2.0307196054455363
#
# Alpha 0.02, Beta 0.25
# Mean Metric Value:  2.0156711452213028
#
# Alpha 0.02, Beta 0.26
# Mean Metric Value:  2.001346847833412
#
# Alpha 0.02, Beta 0.27
# Mean Metric Value:  1.9883167585163644
#
# Alpha 0.02, Beta 0.28
# Mean Metric Value:  1.9773053560343778
#
# Alpha 0.02, Beta 0.29
# Mean Metric Value:  1.9688398918053724
#
# Alpha 0.02, Beta 0.3
# Mean Metric Value:  1.9631306551777032
#
# Alpha 0.02, Beta 0.31
# Mean Metric Value:  1.9601214250640016
#
# Alpha 0.02, Beta 0.32
# Mean Metric Value:  1.9595848908875197
#
# Alpha 0.02, Beta 0.33
# Mean Metric Value:  1.9611770703317768
#
# Alpha 0.02, Beta 0.34
# Mean Metric Value:  1.9644339897716026
#
# Alpha 0.02, Beta 0.35000000000000003
# Mean Metric Value:  1.9687542783945433
#
# Alpha 0.02, Beta 0.36
# Mean Metric Value:  1.9734248399144916
#
# Alpha 0.02, Beta 0.37
# Mean Metric Value:  1.9777111620861356
#
# Alpha 0.02, Beta 0.38
# Mean Metric Value:  1.9809944283947678
#
# Alpha 0.02, Beta 0.39
# Mean Metric Value:  1.9829235743805498
#
# Alpha 0.02, Beta 0.4
# Mean Metric Value:  1.9835458337771767
#
# Alpha 0.02, Beta 0.41000000000000003
# Mean Metric Value:  1.983369695195346
#
# Alpha 0.02, Beta 0.42
# Mean Metric Value:  1.9833185907713227
#
# Alpha 0.02, Beta 0.43
# Mean Metric Value:  1.9845713270078467
#
# Alpha 0.02, Beta 0.44
# Mean Metric Value:  1.9883371264229734
#
# Alpha 0.02, Beta 0.45
# Mean Metric Value:  1.9956380950398054
#
# Alpha 0.02, Beta 0.46
# Mean Metric Value:  2.0071526462929254
#
# Alpha 0.02, Beta 0.47000000000000003
# Mean Metric Value:  2.0231317832287186
#
# Alpha 0.02, Beta 0.48
# Mean Metric Value:  2.0433723068832257
#
# Alpha 0.02, Beta 0.49
# Mean Metric Value:  2.067234361617774
#
# Alpha 0.02, Beta 0.5
# Mean Metric Value:  2.09370773585024
#
# Alpha 0.02, Beta 0.51
# Mean Metric Value:  2.121528915308085
#
# Alpha 0.02, Beta 0.52
# Mean Metric Value:  2.1493284814257576
#
# Alpha 0.02, Beta 0.53
# Mean Metric Value:  2.175776205317261
#
# Alpha 0.02, Beta 0.54
# Mean Metric Value:  2.1996973978828884
#
# Alpha 0.02, Beta 0.55
# Mean Metric Value:  2.2201452106898234
#
# Alpha 0.02, Beta 0.56
# Mean Metric Value:  2.236424452161615
#
# Alpha 0.02, Beta 0.5700000000000001
# Mean Metric Value:  2.2480752115713343
#
# Alpha 0.02, Beta 0.58
# Mean Metric Value:  2.254837109420323
#
# Alpha 0.02, Beta 0.59
# Mean Metric Value:  2.2566199850248205
#
# Alpha 0.02, Beta 0.6
# Mean Metric Value:  2.253498313750207
#
# Alpha 0.02, Beta 0.61
# Mean Metric Value:  2.2457274056783354
#
# Alpha 0.02, Beta 0.62
# Mean Metric Value:  2.2337612891789327
#
# Alpha 0.02, Beta 0.63
# Mean Metric Value:  2.218247124890448
#
# Alpha 0.02, Beta 0.64
# Mean Metric Value:  2.1999816581112537
#
# Alpha 0.02, Beta 0.65
# Mean Metric Value:  2.1798337642696257
#
# Alpha 0.02, Beta 0.66
# Mean Metric Value:  2.1586522532152634
#
# Alpha 0.02, Beta 0.67
# Mean Metric Value:  2.137182747968379
#
# Alpha 0.02, Beta 0.68
# Mean Metric Value:  2.1160118736635205
#
# Alpha 0.02, Beta 0.6900000000000001
# Mean Metric Value:  2.0955463385856947
#
# Alpha 0.02, Beta 0.7000000000000001
# Mean Metric Value:  2.076024287645876
#
# Alpha 0.02, Beta 0.71
# Mean Metric Value:  2.0575494712334352
#
# Alpha 0.02, Beta 0.72
# Mean Metric Value:  2.0401357565208906
#
# Alpha 0.02, Beta 0.73
# Mean Metric Value:  2.0237499485796686
#
# Alpha 0.02, Beta 0.74
# Mean Metric Value:  2.008344248119159
#
# Alpha 0.02, Beta 0.75
# Mean Metric Value:  1.993874701180979
#
# Alpha 0.02, Beta 0.76
# Mean Metric Value:  1.980306653269341
#
# Alpha 0.02, Beta 0.77
# Mean Metric Value:  1.96761080070452
#
# Alpha 0.02, Beta 0.78
# Mean Metric Value:  1.9557536992553173
#
# Alpha 0.02, Beta 0.79
# Mean Metric Value:  1.9446856667416732
#
# Alpha 0.02, Beta 0.8
# Mean Metric Value:  1.9343282990368256
#
# Alpha 0.02, Beta 0.81
# Mean Metric Value:  1.924563983498823
#
# Alpha 0.02, Beta 0.8200000000000001
# Mean Metric Value:  1.9152304820932673
#
# Alpha 0.02, Beta 0.8300000000000001
# Mean Metric Value:  1.9061238611344804
#
# Alpha 0.02, Beta 0.84
# Mean Metric Value:  1.8970119011892872
#
# Alpha 0.02, Beta 0.85
# Mean Metric Value:  1.8876575691568012
#
# Alpha 0.02, Beta 0.86
# Mean Metric Value:  1.8778490055336705
#
# Alpha 0.02, Beta 0.87
# Mean Metric Value:  1.8674300312648917
#
# Alpha 0.02, Beta 0.88
# Mean Metric Value:  1.856324445925385
#
# Alpha 0.02, Beta 0.89
# Mean Metric Value:  1.844548697548782
#
# Alpha 0.02, Beta 0.9
# Mean Metric Value:  1.832210341723117
#
# Alpha 0.02, Beta 0.91
# Mean Metric Value:  1.8194930179885134
#
# Alpha 0.02, Beta 0.92
# Mean Metric Value:  1.8066314511719506
#
# Alpha 0.02, Beta 0.93
# Mean Metric Value:  1.793881786615943
#
# Alpha 0.02, Beta 0.9400000000000001
# Mean Metric Value:  1.7814933774654607
#
# Alpha 0.02, Beta 0.9500000000000001
# Mean Metric Value:  1.769687658474325
#
# Alpha 0.02, Beta 0.96
# Mean Metric Value:  1.758647334461286
#
# Alpha 0.02, Beta 0.97
# Mean Metric Value:  1.7485152686653218
#
# Alpha 0.02, Beta 0.98
# Mean Metric Value:  1.7393994085264513
#
# Alpha 0.02, Beta 0.99
# Mean Metric Value:  1.7313796138875415
#
# Alpha 0.03, Beta 0.0
# Mean Metric Value:  2.3033834172713146
#
# Alpha 0.03, Beta 0.01
# Mean Metric Value:  1.9428698714362116
#
# Alpha 0.03, Beta 0.02
# Mean Metric Value:  1.8838526246486005
#
# Alpha 0.03, Beta 0.03
# Mean Metric Value:  1.85832986545134
#
# Alpha 0.03, Beta 0.04
# Mean Metric Value:  1.8574369974997385
#
# Alpha 0.03, Beta 0.05
# Mean Metric Value:  1.870979053518676
#
# Alpha 0.03, Beta 0.06
# Mean Metric Value:  1.8844597025444025
#
# Alpha 0.03, Beta 0.07
# Mean Metric Value:  1.8872763550834688
#
# Alpha 0.03, Beta 0.08
# Mean Metric Value:  1.8784170841048935
#
# Alpha 0.03, Beta 0.09
# Mean Metric Value:  1.8615798243405033
#
# Alpha 0.03, Beta 0.1
# Mean Metric Value:  1.8397121403340355
#
# Alpha 0.03, Beta 0.11
# Mean Metric Value:  1.8145759598258655
#
# Alpha 0.03, Beta 0.12
# Mean Metric Value:  1.7882056651350138
#
# Alpha 0.03, Beta 0.13
# Mean Metric Value:  1.7628460870885876
#
# Alpha 0.03, Beta 0.14
# Mean Metric Value:  1.7400625377358523
#
# Alpha 0.03, Beta 0.15
# Mean Metric Value:  1.720411097079429
#
# Alpha 0.03, Beta 0.16
# Mean Metric Value:  1.7037615874881702
#
# Alpha 0.03, Beta 0.17
# Mean Metric Value:  1.6898104934808527
#
# Alpha 0.03, Beta 0.18
# Mean Metric Value:  1.6784076618344435
#
# Alpha 0.03, Beta 0.19
# Mean Metric Value:  1.6695756255041667
#
# Alpha 0.03, Beta 0.2
# Mean Metric Value:  1.6633472732717198
#
# Alpha 0.03, Beta 0.21
# Mean Metric Value:  1.6596188666394645
#
# Alpha 0.03, Beta 0.22
# Mean Metric Value:  1.6581062141504432
#
# Alpha 0.03, Beta 0.23
# Mean Metric Value:  1.6583851169038124
#
# Alpha 0.03, Beta 0.24
# Mean Metric Value:  1.6599804535474527
#
# Alpha 0.03, Beta 0.25
# Mean Metric Value:  1.662483334880263
#
# Alpha 0.03, Beta 0.26
# Mean Metric Value:  1.6656688805483462
#
# Alpha 0.03, Beta 0.27
# Mean Metric Value:  1.6695692311939136
#
# Alpha 0.03, Beta 0.28
# Mean Metric Value:  1.6744590680520528
#
# Alpha 0.03, Beta 0.29
# Mean Metric Value:  1.6807437423464797
#
# Alpha 0.03, Beta 0.3
# Mean Metric Value:  1.6887852944952313
#
# Alpha 0.03, Beta 0.31
# Mean Metric Value:  1.6987298536233553
#
# Alpha 0.03, Beta 0.32
# Mean Metric Value:  1.710395143961319
#
# Alpha 0.03, Beta 0.33
# Mean Metric Value:  1.7232485877464458
#
# Alpha 0.03, Beta 0.34
# Mean Metric Value:  1.7364743846370974
#
# Alpha 0.03, Beta 0.35000000000000003
# Mean Metric Value:  1.7491030555973426
#
# Alpha 0.03, Beta 0.36
# Mean Metric Value:  1.760163328226017
#
# Alpha 0.03, Beta 0.37
# Mean Metric Value:  1.76881718275831
#
# Alpha 0.03, Beta 0.38
# Mean Metric Value:  1.7744530440068953
#
# Alpha 0.03, Beta 0.39
# Mean Metric Value:  1.7767309315576947
#
# Alpha 0.03, Beta 0.4
# Mean Metric Value:  1.7755867501003455
#
# Alpha 0.03, Beta 0.41000000000000003
# Mean Metric Value:  1.7712063257656798
#
# Alpha 0.03, Beta 0.42
# Mean Metric Value:  1.7639768168206809
#
# Alpha 0.03, Beta 0.43
# Mean Metric Value:  1.7544210461294614
#
# Alpha 0.03, Beta 0.44
# Mean Metric Value:  1.7431228028058097
#
# Alpha 0.03, Beta 0.45
# Mean Metric Value:  1.7306553518136019
#
# Alpha 0.03, Beta 0.46
# Mean Metric Value:  1.7175259490798398
#
# Alpha 0.03, Beta 0.47000000000000003
# Mean Metric Value:  1.7041441043608978
#
# Alpha 0.03, Beta 0.48
# Mean Metric Value:  1.6908133784428527
#
# Alpha 0.03, Beta 0.49
# Mean Metric Value:  1.677740033839867
#
# Alpha 0.03, Beta 0.5
# Mean Metric Value:  1.6650495498724494
#
# Alpha 0.03, Beta 0.51
# Mean Metric Value:  1.652803716998875
#
# Alpha 0.03, Beta 0.52
# Mean Metric Value:  1.6410147708659808
#
# Alpha 0.03, Beta 0.53
# Mean Metric Value:  1.6296566452425163
#
# Alpha 0.03, Beta 0.54
# Mean Metric Value:  1.6186755953046505
#
# Alpha 0.03, Beta 0.55
# Mean Metric Value:  1.608002814040655
#
# Alpha 0.03, Beta 0.56
# Mean Metric Value:  1.5975704757777787
#
# Alpha 0.03, Beta 0.5700000000000001
# Mean Metric Value:  1.587330456223767
#
# Alpha 0.03, Beta 0.58
# Mean Metric Value:  1.5772726025040955
#
# Alpha 0.03, Beta 0.59
# Mean Metric Value:  1.5674377479166448
#
# Alpha 0.03, Beta 0.6
# Mean Metric Value:  1.5579204337211081
#
# Alpha 0.03, Beta 0.61
# Mean Metric Value:  1.548858215501991
#
# Alpha 0.03, Beta 0.62
# Mean Metric Value:  1.5404092209089457
#
# Alpha 0.03, Beta 0.63
# Mean Metric Value:  1.5327262411721714
#
# Alpha 0.03, Beta 0.64
# Mean Metric Value:  1.525938584247281
#
# Alpha 0.03, Beta 0.65
# Mean Metric Value:  1.5201469955489528
#
# Alpha 0.03, Beta 0.66
# Mean Metric Value:  1.5154273350510048
#
# Alpha 0.03, Beta 0.67
# Mean Metric Value:  1.5118355339233123
#
# Alpha 0.03, Beta 0.68
# Mean Metric Value:  1.5094100681864044
#
# Alpha 0.03, Beta 0.6900000000000001
# Mean Metric Value:  1.5081721990131873
#
# Alpha 0.03, Beta 0.7000000000000001
# Mean Metric Value:  1.5081254785359177
#
# Alpha 0.03, Beta 0.71
# Mean Metric Value:  1.5092555842257998
#
# Alpha 0.03, Beta 0.72
# Mean Metric Value:  1.5115308558067932
#
# Alpha 0.03, Beta 0.73
# Mean Metric Value:  1.5149034746186811
#
# Alpha 0.03, Beta 0.74
# Mean Metric Value:  1.5193110446512357
#
# Alpha 0.03, Beta 0.75
# Mean Metric Value:  1.5246783073142653
#
# Alpha 0.03, Beta 0.76
# Mean Metric Value:  1.530918774170897
#
# Alpha 0.03, Beta 0.77
# Mean Metric Value:  1.5379361506770828
#
# Alpha 0.03, Beta 0.78
# Mean Metric Value:  1.5456255285498006
#
# Alpha 0.03, Beta 0.79
# Mean Metric Value:  1.5538744357982448
#
# Alpha 0.03, Beta 0.8
# Mean Metric Value:  1.5625639409613061
#
# Alpha 0.03, Beta 0.81
# Mean Metric Value:  1.5715700877767569
#
# Alpha 0.03, Beta 0.8200000000000001
# Mean Metric Value:  1.5807659534686385
#
# Alpha 0.03, Beta 0.8300000000000001
# Mean Metric Value:  1.5900245492664313
#
# Alpha 0.03, Beta 0.84
# Mean Metric Value:  1.5992226127356035
#
# Alpha 0.03, Beta 0.85
# Mean Metric Value:  1.6082451092652235
#
# Alpha 0.03, Beta 0.86
# Mean Metric Value:  1.6169900220750952
#
# Alpha 0.03, Beta 0.87
# Mean Metric Value:  1.6253728310401543
#
# Alpha 0.03, Beta 0.88
# Mean Metric Value:  1.6333300112437086
#
# Alpha 0.03, Beta 0.89
# Mean Metric Value:  1.6408209438159649
#
# Alpha 0.03, Beta 0.9
# Mean Metric Value:  1.6478278117512621
#
# Alpha 0.03, Beta 0.91
# Mean Metric Value:  1.6543533134363837
#
# Alpha 0.03, Beta 0.92
# Mean Metric Value:  1.6604163172685327
#
# Alpha 0.03, Beta 0.93
# Mean Metric Value:  1.6660458560493852
#
# Alpha 0.03, Beta 0.9400000000000001
# Mean Metric Value:  1.6712740837453461
#
# Alpha 0.03, Beta 0.9500000000000001
# Mean Metric Value:  1.6761289635661147
#
# Alpha 0.03, Beta 0.96
# Mean Metric Value:  1.6806275083060067
#
# Alpha 0.03, Beta 0.97
# Mean Metric Value:  1.684770346464041
#
# Alpha 0.03, Beta 0.98
# Mean Metric Value:  1.688538250790563
#
# Alpha 0.03, Beta 0.99
# Mean Metric Value:  1.6918910632908575
#
# Alpha 0.04, Beta 0.0
# Mean Metric Value:  1.9193574826113702
#
# Alpha 0.04, Beta 0.01
# Mean Metric Value:  1.6573386099305334
#
# Alpha 0.04, Beta 0.02
# Mean Metric Value:  1.6208920001988574
#
# Alpha 0.04, Beta 0.03
# Mean Metric Value:  1.6099683172714225
#
# Alpha 0.04, Beta 0.04
# Mean Metric Value:  1.6108915668720336
#
# Alpha 0.04, Beta 0.05
# Mean Metric Value:  1.6115894208106
#
# Alpha 0.04, Beta 0.06
# Mean Metric Value:  1.6054788117804653
#
# Alpha 0.04, Beta 0.07
# Mean Metric Value:  1.5924513261393913
#
# Alpha 0.04, Beta 0.08
# Mean Metric Value:  1.5748966322956859
#
# Alpha 0.04, Beta 0.09
# Mean Metric Value:  1.5552854227331836
#
# Alpha 0.04, Beta 0.1
# Mean Metric Value:  1.5357972900723447
#
# Alpha 0.04, Beta 0.11
# Mean Metric Value:  1.5180443636984253
#
# Alpha 0.04, Beta 0.12
# Mean Metric Value:  1.502874913882129
#
# Alpha 0.04, Beta 0.13
# Mean Metric Value:  1.490556409657852
#
# Alpha 0.04, Beta 0.14
# Mean Metric Value:  1.4810807472443581
#
# Alpha 0.04, Beta 0.15
# Mean Metric Value:  1.474328608049183
#
# Alpha 0.04, Beta 0.16
# Mean Metric Value:  1.470091246961933
#
# Alpha 0.04, Beta 0.17
# Mean Metric Value:  1.4680674926231503
#
# Alpha 0.04, Beta 0.18
# Mean Metric Value:  1.46790534608569
#
# Alpha 0.04, Beta 0.19
# Mean Metric Value:  1.4692793551949777
#
# Alpha 0.04, Beta 0.2
# Mean Metric Value:  1.471957743549024
#
# Alpha 0.04, Beta 0.21
# Mean Metric Value:  1.4758142815724986
#
# Alpha 0.04, Beta 0.22
# Mean Metric Value:  1.4807690392167163
#
# Alpha 0.04, Beta 0.23
# Mean Metric Value:  1.48668449376263
#
# Alpha 0.04, Beta 0.24
# Mean Metric Value:  1.4932716539843875
#
# Alpha 0.04, Beta 0.25
# Mean Metric Value:  1.5000557419777976
#
# Alpha 0.04, Beta 0.26
# Mean Metric Value:  1.5064187128561752
#
# Alpha 0.04, Beta 0.27
# Mean Metric Value:  1.5116993846138866
#
# Alpha 0.04, Beta 0.28
# Mean Metric Value:  1.5153111411689624
#
# Alpha 0.04, Beta 0.29
# Mean Metric Value:  1.5168381098876462
#
# Alpha 0.04, Beta 0.3
# Mean Metric Value:  1.5160865352987776
#
# Alpha 0.04, Beta 0.31
# Mean Metric Value:  1.513086948644417
#
# Alpha 0.04, Beta 0.32
# Mean Metric Value:  1.5080564300089625
#
# Alpha 0.04, Beta 0.33
# Mean Metric Value:  1.501337043041746
#
# Alpha 0.04, Beta 0.34
# Mean Metric Value:  1.4933279738216403
#
# Alpha 0.04, Beta 0.35000000000000003
# Mean Metric Value:  1.4844263024149347
#
# Alpha 0.04, Beta 0.36
# Mean Metric Value:  1.4749855854197258
#
# Alpha 0.04, Beta 0.37
# Mean Metric Value:  1.4652945118612897
#
# Alpha 0.04, Beta 0.38
# Mean Metric Value:  1.4555725133855288
#
# Alpha 0.04, Beta 0.39
# Mean Metric Value:  1.4459769562034228
#
# Alpha 0.04, Beta 0.4
# Mean Metric Value:  1.436616973949162
#
# Alpha 0.04, Beta 0.41000000000000003
# Mean Metric Value:  1.4275704308476875
#
# Alpha 0.04, Beta 0.42
# Mean Metric Value:  1.4189014343145523
#
# Alpha 0.04, Beta 0.43
# Mean Metric Value:  1.4106758008992695
#
# Alpha 0.04, Beta 0.44
# Mean Metric Value:  1.4029715364297386
#
# Alpha 0.04, Beta 0.45
# Mean Metric Value:  1.3958818469989174
#
# Alpha 0.04, Beta 0.46
# Mean Metric Value:  1.3895102410592044
#
# Alpha 0.04, Beta 0.47000000000000003
# Mean Metric Value:  1.3839603897112378
#
# Alpha 0.04, Beta 0.48
# Mean Metric Value:  1.3793254599769795
#
# Alpha 0.04, Beta 0.49
# Mean Metric Value:  1.3756806855526433
#
# Alpha 0.04, Beta 0.5
# Mean Metric Value:  1.373079863443774
#
# Alpha 0.04, Beta 0.51
# Mean Metric Value:  1.3715542188268992
#
# Alpha 0.04, Beta 0.52
# Mean Metric Value:  1.3711120528400835
#
# Alpha 0.04, Beta 0.53
# Mean Metric Value:  1.37173863880533
#
# Alpha 0.04, Beta 0.54
# Mean Metric Value:  1.3733965546481661
#
# Alpha 0.04, Beta 0.55
# Mean Metric Value:  1.376026732384017
#
# Alpha 0.04, Beta 0.56
# Mean Metric Value:  1.3795503095735429
#
# Alpha 0.04, Beta 0.5700000000000001
# Mean Metric Value:  1.3838711882307964
#
# Alpha 0.04, Beta 0.58
# Mean Metric Value:  1.3888791427664215
#
# Alpha 0.04, Beta 0.59
# Mean Metric Value:  1.3944533449742664
#
# Alpha 0.04, Beta 0.6
# Mean Metric Value:  1.4004662291256802
#
# Alpha 0.04, Beta 0.61
# Mean Metric Value:  1.4067876477823884
#
# Alpha 0.04, Beta 0.62
# Mean Metric Value:  1.4132892354628872
#
# Alpha 0.04, Beta 0.63
# Mean Metric Value:  1.4198488004363359
#
# Alpha 0.04, Beta 0.64
# Mean Metric Value:  1.4263544351624229
#
# Alpha 0.04, Beta 0.65
# Mean Metric Value:  1.4327079273591723
#
# Alpha 0.04, Beta 0.66
# Mean Metric Value:  1.4388270238360694
#
# Alpha 0.04, Beta 0.67
# Mean Metric Value:  1.4446461850646273
#
# Alpha 0.04, Beta 0.68
# Mean Metric Value:  1.4501156700562323
#
# Alpha 0.04, Beta 0.6900000000000001
# Mean Metric Value:  1.4551990700218171
#
# Alpha 0.04, Beta 0.7000000000000001
# Mean Metric Value:  1.4598697011280921
#
# Alpha 0.04, Beta 0.71
# Mean Metric Value:  1.464106501168522
#
# Alpha 0.04, Beta 0.72
# Mean Metric Value:  1.4678901951760084
#
# Alpha 0.04, Beta 0.73
# Mean Metric Value:  1.4712004703175687
#
# Alpha 0.04, Beta 0.74
# Mean Metric Value:  1.474014731722112
#
# Alpha 0.04, Beta 0.75
# Mean Metric Value:  1.4763087284344658
#
# Alpha 0.04, Beta 0.76
# Mean Metric Value:  1.478058994516171
#
# Alpha 0.04, Beta 0.77
# Mean Metric Value:  1.479246708004999
#
# Alpha 0.04, Beta 0.78
# Mean Metric Value:  1.4798622943075113
#
# Alpha 0.04, Beta 0.79
# Mean Metric Value:  1.4799099451468978
#
# Alpha 0.04, Beta 0.8
# Mean Metric Value:  1.4794112236301602
#
# Alpha 0.04, Beta 0.81
# Mean Metric Value:  1.4784070845800201
#
# Alpha 0.04, Beta 0.8200000000000001
# Mean Metric Value:  1.4769579259988168
#
# Alpha 0.04, Beta 0.8300000000000001
# Mean Metric Value:  1.4751416399352004
#
# Alpha 0.04, Beta 0.84
# Mean Metric Value:  1.4730499700177848
#
# Alpha 0.04, Beta 0.85
# Mean Metric Value:  1.4707837349568171
#
# Alpha 0.04, Beta 0.86
# Mean Metric Value:  1.4684475955960399
#
# Alpha 0.04, Beta 0.87
# Mean Metric Value:  1.466145019184125
#
# Alpha 0.04, Beta 0.88
# Mean Metric Value:  1.463973956306983
#
# Alpha 0.04, Beta 0.89
# Mean Metric Value:  1.4620235441540934
#
# Alpha 0.04, Beta 0.9
# Mean Metric Value:  1.460371940002547
#
# Alpha 0.04, Beta 0.91
# Mean Metric Value:  1.4590852155852232
#
# Alpha 0.04, Beta 0.92
# Mean Metric Value:  1.4582171312791259
#
# Alpha 0.04, Beta 0.93
# Mean Metric Value:  1.4578095630200794
#
# Alpha 0.04, Beta 0.9400000000000001
# Mean Metric Value:  1.4578933627430677
#
# Alpha 0.04, Beta 0.9500000000000001
# Mean Metric Value:  1.4584894746214128
#
# Alpha 0.04, Beta 0.96
# Mean Metric Value:  1.4596101828993189
#
# Alpha 0.04, Beta 0.97
# Mean Metric Value:  1.4612604154476792
#
# Alpha 0.04, Beta 0.98
# Mean Metric Value:  1.4634390602157354
#
# Alpha 0.04, Beta 0.99
# Mean Metric Value:  1.4661402668195551
#
# Alpha 0.05, Beta 0.0
# Mean Metric Value:  1.6691929009506754
#
# Alpha 0.05, Beta 0.01
# Mean Metric Value:  1.4680836182929005
#
# Alpha 0.05, Beta 0.02
# Mean Metric Value:  1.4428728865888372
#
# Alpha 0.05, Beta 0.03
# Mean Metric Value:  1.4350973834925513
#
# Alpha 0.05, Beta 0.04
# Mean Metric Value:  1.4316099388071377
#
# Alpha 0.05, Beta 0.05
# Mean Metric Value:  1.424876514099437
#
# Alpha 0.05, Beta 0.06
# Mean Metric Value:  1.4133842181528324
#
# Alpha 0.05, Beta 0.07
# Mean Metric Value:  1.3988138674684172
#
# Alpha 0.05, Beta 0.08
# Mean Metric Value:  1.383429071344013
#
# Alpha 0.05, Beta 0.09
# Mean Metric Value:  1.3690625740948592
#
# Alpha 0.05, Beta 0.1
# Mean Metric Value:  1.356825007843891
#
# Alpha 0.05, Beta 0.11
# Mean Metric Value:  1.3471810574875231
#
# Alpha 0.05, Beta 0.12
# Mean Metric Value:  1.340181643799005
#
# Alpha 0.05, Beta 0.13
# Mean Metric Value:  1.3356502548752025
#
# Alpha 0.05, Beta 0.14
# Mean Metric Value:  1.3332887687712107
#
# Alpha 0.05, Beta 0.15
# Mean Metric Value:  1.332748864867755
#
# Alpha 0.05, Beta 0.16
# Mean Metric Value:  1.333685887642634
#
# Alpha 0.05, Beta 0.17
# Mean Metric Value:  1.3357785941152898
#
# Alpha 0.05, Beta 0.18
# Mean Metric Value:  1.3387060077266206
#
# Alpha 0.05, Beta 0.19
# Mean Metric Value:  1.3421030372768503
#
# Alpha 0.05, Beta 0.2
# Mean Metric Value:  1.3455345737977147
#
# Alpha 0.05, Beta 0.21
# Mean Metric Value:  1.348515903268499
#
# Alpha 0.05, Beta 0.22
# Mean Metric Value:  1.350576506592963
#
# Alpha 0.05, Beta 0.23
# Mean Metric Value:  1.3513389999900287
#
# Alpha 0.05, Beta 0.24
# Mean Metric Value:  1.3505800362736209
#
# Alpha 0.05, Beta 0.25
# Mean Metric Value:  1.3482529238299956
#
# Alpha 0.05, Beta 0.26
# Mean Metric Value:  1.3444704451530123
#
# Alpha 0.05, Beta 0.27
# Mean Metric Value:  1.3394603722829441
#
# Alpha 0.05, Beta 0.28
# Mean Metric Value:  1.3335114238527228
#
# Alpha 0.05, Beta 0.29
# Mean Metric Value:  1.326925027258288
#
# Alpha 0.05, Beta 0.3
# Mean Metric Value:  1.3199817530311782
#
# Alpha 0.05, Beta 0.31
# Mean Metric Value:  1.3129244087426313
#
# Alpha 0.05, Beta 0.32
# Mean Metric Value:  1.3059549703442075
#
# Alpha 0.05, Beta 0.33
# Mean Metric Value:  1.2992403610172478
#
# Alpha 0.05, Beta 0.34
# Mean Metric Value:  1.2929218493786392
#
# Alpha 0.05, Beta 0.35000000000000003
# Mean Metric Value:  1.2871236736972371
#
# Alpha 0.05, Beta 0.36
# Mean Metric Value:  1.2819580147731984
#
# Alpha 0.05, Beta 0.37
# Mean Metric Value:  1.277525442609985
#
# Alpha 0.05, Beta 0.38
# Mean Metric Value:  1.2739119043352798
#
# Alpha 0.05, Beta 0.39
# Mean Metric Value:  1.271184354265373
#
# Alpha 0.05, Beta 0.4
# Mean Metric Value:  1.269386875057493
#
# Alpha 0.05, Beta 0.41000000000000003
# Mean Metric Value:  1.2685381720302593
#
# Alpha 0.05, Beta 0.42
# Mean Metric Value:  1.2686305426121385
#
# Alpha 0.05, Beta 0.43
# Mean Metric Value:  1.2696301771534069
#
# Alpha 0.05, Beta 0.44
# Mean Metric Value:  1.2714786924169068
#
# Alpha 0.05, Beta 0.45
# Mean Metric Value:  1.27409583260552
#
# Alpha 0.05, Beta 0.46
# Mean Metric Value:  1.2773832154165154
#
# Alpha 0.05, Beta 0.47000000000000003
# Mean Metric Value:  1.281228909606373
#
# Alpha 0.05, Beta 0.48
# Mean Metric Value:  1.2855125583891467
#
# Alpha 0.05, Beta 0.49
# Mean Metric Value:  1.2901107167389558
#
# Alpha 0.05, Beta 0.5
# Mean Metric Value:  1.2949020378525558
#
# Alpha 0.05, Beta 0.51
# Mean Metric Value:  1.2997719236229865
#
# Alpha 0.05, Beta 0.52
# Mean Metric Value:  1.30461626604547
#
# Alpha 0.05, Beta 0.53
# Mean Metric Value:  1.3093439802725175
#
# Alpha 0.05, Beta 0.54
# Mean Metric Value:  1.3138781818783554
#
# Alpha 0.05, Beta 0.55
# Mean Metric Value:  1.3181560764800948
#
# Alpha 0.05, Beta 0.56
# Mean Metric Value:  1.3221278618317198
#
# Alpha 0.05, Beta 0.5700000000000001
# Mean Metric Value:  1.3257551251084112
#
# Alpha 0.05, Beta 0.58
# Mean Metric Value:  1.3290092917258793
#
# Alpha 0.05, Beta 0.59
# Mean Metric Value:  1.3318706162779366
#
# Alpha 0.05, Beta 0.6
# Mean Metric Value:  1.3343280120508065
#
# Alpha 0.05, Beta 0.61
# Mean Metric Value:  1.3363797432225029
#
# Alpha 0.05, Beta 0.62
# Mean Metric Value:  1.3380347274444553
#
# Alpha 0.05, Beta 0.63
# Mean Metric Value:  1.3393139918837775
#
# Alpha 0.05, Beta 0.64
# Mean Metric Value:  1.3402517478871177
#
# Alpha 0.05, Beta 0.65
# Mean Metric Value:  1.340895615936761
#
# Alpha 0.05, Beta 0.66
# Mean Metric Value:  1.3413057193026634
#
# Alpha 0.05, Beta 0.67
# Mean Metric Value:  1.341552614318414
#
# Alpha 0.05, Beta 0.68
# Mean Metric Value:  1.3417142664389223
#
# Alpha 0.05, Beta 0.6900000000000001
# Mean Metric Value:  1.3418724528201282
#
# Alpha 0.05, Beta 0.7000000000000001
# Mean Metric Value:  1.3421090406732739
#
# Alpha 0.05, Beta 0.71
# Mean Metric Value:  1.3425025569677647
#
# Alpha 0.05, Beta 0.72
# Mean Metric Value:  1.3431253578381783
#
# Alpha 0.05, Beta 0.73
# Mean Metric Value:  1.3440415669086256
#
# Alpha 0.05, Beta 0.74
# Mean Metric Value:  1.34530581945579
#
# Alpha 0.05, Beta 0.75
# Mean Metric Value:  1.3469627491154683
#
# Alpha 0.05, Beta 0.76
# Mean Metric Value:  1.3490470942602848
#
# Alpha 0.05, Beta 0.77
# Mean Metric Value:  1.35158427747378
#
# Alpha 0.05, Beta 0.78
# Mean Metric Value:  1.3545913121591864
#
# Alpha 0.05, Beta 0.79
# Mean Metric Value:  1.35807790328374
#
# Alpha 0.05, Beta 0.8
# Mean Metric Value:  1.3620476262400376
#
# Alpha 0.05, Beta 0.81
# Mean Metric Value:  1.366499085237393
#
# Alpha 0.05, Beta 0.8200000000000001
# Mean Metric Value:  1.3714269705702373
#
# Alpha 0.05, Beta 0.8300000000000001
# Mean Metric Value:  1.3768229540684989
#
# Alpha 0.05, Beta 0.84
# Mean Metric Value:  1.382676385025075
#
# Alpha 0.05, Beta 0.85
# Mean Metric Value:  1.3889747743319196
#
# Alpha 0.05, Beta 0.86
# Mean Metric Value:  1.3957040802273195
#
# Alpha 0.05, Beta 0.87
# Mean Metric Value:  1.4028488318296175
#
# Alpha 0.05, Beta 0.88
# Mean Metric Value:  1.4103921434181426
#
# Alpha 0.05, Beta 0.89
# Mean Metric Value:  1.418315680957154
#
# Alpha 0.05, Beta 0.9
# Mean Metric Value:  1.4265996416074798
#
# Alpha 0.05, Beta 0.91
# Mean Metric Value:  1.435222797159765
#
# Alpha 0.05, Beta 0.92
# Mean Metric Value:  1.444162634778473
#
# Alpha 0.05, Beta 0.93
# Mean Metric Value:  1.45339560537677
#
# Alpha 0.05, Beta 0.9400000000000001
# Mean Metric Value:  1.462897464263828
#
# Alpha 0.05, Beta 0.9500000000000001
# Mean Metric Value:  1.4726436638431037
#
# Alpha 0.05, Beta 0.96
# Mean Metric Value:  1.4826097377452614
#
# Alpha 0.05, Beta 0.97
# Mean Metric Value:  1.4927716032848712
#
# Alpha 0.05, Beta 0.98
# Mean Metric Value:  1.5031057071734761
#
# Alpha 0.05, Beta 0.99
# Mean Metric Value:  1.513588949254987
#
# Alpha 0.06, Beta 0.0
# Mean Metric Value:  1.4920702592789998
#
# Alpha 0.06, Beta 0.01
# Mean Metric Value:  1.3313933265673736
#
# Alpha 0.06, Beta 0.02
# Mean Metric Value:  1.3121858128413928
#
# Alpha 0.06, Beta 0.03
# Mean Metric Value:  1.3047985011652254
#
# Alpha 0.06, Beta 0.04
# Mean Metric Value:  1.298639707468241
#
# Alpha 0.06, Beta 0.05
# Mean Metric Value:  1.2896038903398974
#
# Alpha 0.06, Beta 0.06
# Mean Metric Value:  1.278047852197185
#
# Alpha 0.06, Beta 0.07
# Mean Metric Value:  1.2658191200592706
#
# Alpha 0.06, Beta 0.08
# Mean Metric Value:  1.2545761581606558
#
# Alpha 0.06, Beta 0.09
# Mean Metric Value:  1.245298733314915
#
# Alpha 0.06, Beta 0.1
# Mean Metric Value:  1.2383445925783054
#
# Alpha 0.06, Beta 0.11
# Mean Metric Value:  1.233666073227309
#
# Alpha 0.06, Beta 0.12
# Mean Metric Value:  1.230996716403678
#
# Alpha 0.06, Beta 0.13
# Mean Metric Value:  1.229970071785831
#
# Alpha 0.06, Beta 0.14
# Mean Metric Value:  1.2301845517553807
#
# Alpha 0.06, Beta 0.15
# Mean Metric Value:  1.2312271948213733
#
# Alpha 0.06, Beta 0.16
# Mean Metric Value:  1.2326743765173518
#
# Alpha 0.06, Beta 0.17
# Mean Metric Value:  1.2340963335911121
#
# Alpha 0.06, Beta 0.18
# Mean Metric Value:  1.2350847968691085
#
# Alpha 0.06, Beta 0.19
# Mean Metric Value:  1.2353008684439966
#
# Alpha 0.06, Beta 0.2
# Mean Metric Value:  1.2345223676314467
#
# Alpha 0.06, Beta 0.21
# Mean Metric Value:  1.2326689633915262
#
# Alpha 0.06, Beta 0.22
# Mean Metric Value:  1.2297961930543866
#
# Alpha 0.06, Beta 0.23
# Mean Metric Value:  1.2260642956265073
#
# Alpha 0.06, Beta 0.24
# Mean Metric Value:  1.2216958903406487
#
# Alpha 0.06, Beta 0.25
# Mean Metric Value:  1.216936232933494
#
# Alpha 0.06, Beta 0.26
# Mean Metric Value:  1.2120243182193229
#
# Alpha 0.06, Beta 0.27
# Mean Metric Value:  1.2071767351552507
#
# Alpha 0.06, Beta 0.28
# Mean Metric Value:  1.2025817022146081
#
# Alpha 0.06, Beta 0.29
# Mean Metric Value:  1.1983989004833435
#
# Alpha 0.06, Beta 0.3
# Mean Metric Value:  1.1947610793959802
#
# Alpha 0.06, Beta 0.31
# Mean Metric Value:  1.191774974762753
#
# Alpha 0.06, Beta 0.32
# Mean Metric Value:  1.1895208614554178
#
# Alpha 0.06, Beta 0.33
# Mean Metric Value:  1.1880512989048193
#
# Alpha 0.06, Beta 0.34
# Mean Metric Value:  1.187390034060062
#
# Alpha 0.06, Beta 0.35000000000000003
# Mean Metric Value:  1.1875318362690725
#
# Alpha 0.06, Beta 0.36
# Mean Metric Value:  1.188443669211153
#
# Alpha 0.06, Beta 0.37
# Mean Metric Value:  1.1900673038205174
#
# Alpha 0.06, Beta 0.38
# Mean Metric Value:  1.1923232693487456
#
# Alpha 0.06, Beta 0.39
# Mean Metric Value:  1.1951158818029204
#
# Alpha 0.06, Beta 0.4
# Mean Metric Value:  1.1983389634534636
#
# Alpha 0.06, Beta 0.41000000000000003
# Mean Metric Value:  1.2018817857799757
#
# Alpha 0.06, Beta 0.42
# Mean Metric Value:  1.205634744929593
#
# Alpha 0.06, Beta 0.43
# Mean Metric Value:  1.209494320759707
#
# Alpha 0.06, Beta 0.44
# Mean Metric Value:  1.2133669794742645
#
# Alpha 0.06, Beta 0.45
# Mean Metric Value:  1.217171847641435
#
# Alpha 0.06, Beta 0.46
# Mean Metric Value:  1.220842186159486
#
# Alpha 0.06, Beta 0.47000000000000003
# Mean Metric Value:  1.2243258815328764
#
# Alpha 0.06, Beta 0.48
# Mean Metric Value:  1.2275852962138856
#
# Alpha 0.06, Beta 0.49
# Mean Metric Value:  1.2305968409248191
#
# Alpha 0.06, Beta 0.5
# Mean Metric Value:  1.2333505435811563
#
# Alpha 0.06, Beta 0.51
# Mean Metric Value:  1.2358497241483724
#
# Alpha 0.06, Beta 0.52
# Mean Metric Value:  1.2381107027633789
#
# Alpha 0.06, Beta 0.53
# Mean Metric Value:  1.240162334748257
#
# Alpha 0.06, Beta 0.54
# Mean Metric Value:  1.2420451255716332
#
# Alpha 0.06, Beta 0.55
# Mean Metric Value:  1.2438097400772088
#
# Alpha 0.06, Beta 0.56
# Mean Metric Value:  1.2455148553291138
#
# Alpha 0.06, Beta 0.5700000000000001
# Mean Metric Value:  1.2472244642971417
#
# Alpha 0.06, Beta 0.58
# Mean Metric Value:  1.249004865914231
#
# Alpha 0.06, Beta 0.59
# Mean Metric Value:  1.2509216408801476
#
# Alpha 0.06, Beta 0.6
# Mean Metric Value:  1.253036903559352
#
# Alpha 0.06, Beta 0.61
# Mean Metric Value:  1.2554070536451765
#
# Alpha 0.06, Beta 0.62
# Mean Metric Value:  1.2580811548140138
#
# Alpha 0.06, Beta 0.63
# Mean Metric Value:  1.2610999694375016
#
# Alpha 0.06, Beta 0.64
# Mean Metric Value:  1.2644955982572752
#
# Alpha 0.06, Beta 0.65
# Mean Metric Value:  1.268291620513854
#
# Alpha 0.06, Beta 0.66
# Mean Metric Value:  1.2725036033263821
#
# Alpha 0.06, Beta 0.67
# Mean Metric Value:  1.2771398444084783
#
# Alpha 0.06, Beta 0.68
# Mean Metric Value:  1.282202223557654
#
# Alpha 0.06, Beta 0.6900000000000001
# Mean Metric Value:  1.2876870604697066
#
# Alpha 0.06, Beta 0.7000000000000001
# Mean Metric Value:  1.2935859048765252
#
# Alpha 0.06, Beta 0.71
# Mean Metric Value:  1.2998862157848843
#
# Alpha 0.06, Beta 0.72
# Mean Metric Value:  1.3065719157883802
#
# Alpha 0.06, Beta 0.73
# Mean Metric Value:  1.3136238303327954
#
# Alpha 0.06, Beta 0.74
# Mean Metric Value:  1.3210200374735883
#
# Alpha 0.06, Beta 0.75
# Mean Metric Value:  1.3287361594514009
#
# Alpha 0.06, Beta 0.76
# Mean Metric Value:  1.3367456234411976
#
# Alpha 0.06, Beta 0.77
# Mean Metric Value:  1.3450199069825592
#
# Alpha 0.06, Beta 0.78
# Mean Metric Value:  1.3535287671976493
#
# Alpha 0.06, Beta 0.79
# Mean Metric Value:  1.3622404361301443
#
# Alpha 0.06, Beta 0.8
# Mean Metric Value:  1.3711217516791312
#
# Alpha 0.06, Beta 0.81
# Mean Metric Value:  1.3801381882519443
#
# Alpha 0.06, Beta 0.8200000000000001
# Mean Metric Value:  1.3892537556007112
#
# Alpha 0.06, Beta 0.8300000000000001
# Mean Metric Value:  1.3984307486079475
#
# Alpha 0.06, Beta 0.84
# Mean Metric Value:  1.4076293532602167
#
# Alpha 0.06, Beta 0.85
# Mean Metric Value:  1.4168071411436602
#
# Alpha 0.06, Beta 0.86
# Mean Metric Value:  1.425918511871422
#
# Alpha 0.06, Beta 0.87
# Mean Metric Value:  1.43491416510603
#
# Alpha 0.06, Beta 0.88
# Mean Metric Value:  1.4437406972210334
#
# Alpha 0.06, Beta 0.89
# Mean Metric Value:  1.4523404195739655
#
# Alpha 0.06, Beta 0.9
# Mean Metric Value:  1.4606514850650163
#
# Alpha 0.06, Beta 0.91
# Mean Metric Value:  1.4686083881270102
#
# Alpha 0.06, Beta 0.92
# Mean Metric Value:  1.4761428729414448
#
# Alpha 0.06, Beta 0.93
# Mean Metric Value:  1.4831852488153405
#
# Alpha 0.06, Beta 0.9400000000000001
# Mean Metric Value:  1.4896660739815357
#
# Alpha 0.06, Beta 0.9500000000000001
# Mean Metric Value:  1.4955181332540843
#
# Alpha 0.06, Beta 0.96
# Mean Metric Value:  1.5006786043075238
#
# Alpha 0.06, Beta 0.97
# Mean Metric Value:  1.50509128467174
#
# Alpha 0.06, Beta 0.98
# Mean Metric Value:  1.5087087390347298
#
# Alpha 0.06, Beta 0.99
# Mean Metric Value:  1.5114942255491914
#
# Alpha 0.07, Beta 0.0
# Mean Metric Value:  1.359537285339725
#
# Alpha 0.07, Beta 0.01
# Mean Metric Value:  1.2272908115864203
#
# Alpha 0.07, Beta 0.02
# Mean Metric Value:  1.2117036043593228
#
# Alpha 0.07, Beta 0.03
# Mean Metric Value:  1.2044070293478688
#
# Alpha 0.07, Beta 0.04
# Mean Metric Value:  1.1973147762919905
#
# Alpha 0.07, Beta 0.05
# Mean Metric Value:  1.188321649466275
#
# Alpha 0.07, Beta 0.06
# Mean Metric Value:  1.1783841706477622
#
# Alpha 0.07, Beta 0.07
# Mean Metric Value:  1.1690127012011498
#
# Alpha 0.07, Beta 0.08
# Mean Metric Value:  1.1612253353107074
#
# Alpha 0.07, Beta 0.09
# Mean Metric Value:  1.1554179945503982
#
# Alpha 0.07, Beta 0.1
# Mean Metric Value:  1.1515461480790656
#
# Alpha 0.07, Beta 0.11
# Mean Metric Value:  1.149323658154228
#
# Alpha 0.07, Beta 0.12
# Mean Metric Value:  1.1483559933027487
#
# Alpha 0.07, Beta 0.13
# Mean Metric Value:  1.14821299207423
#
# Alpha 0.07, Beta 0.14
# Mean Metric Value:  1.1484665353611065
#
# Alpha 0.07, Beta 0.15
# Mean Metric Value:  1.1487185280635583
#
# Alpha 0.07, Beta 0.16
# Mean Metric Value:  1.148633605584652
#
# Alpha 0.07, Beta 0.17
# Mean Metric Value:  1.1479737536569328
#
# Alpha 0.07, Beta 0.18
# Mean Metric Value:  1.1466213545367383
#
# Alpha 0.07, Beta 0.19
# Mean Metric Value:  1.1445799881598882
#
# Alpha 0.07, Beta 0.2
# Mean Metric Value:  1.1419531951226178
#
# Alpha 0.07, Beta 0.21
# Mean Metric Value:  1.1389105428604036
#
# Alpha 0.07, Beta 0.22
# Mean Metric Value:  1.1356525829757915
#
# Alpha 0.07, Beta 0.23
# Mean Metric Value:  1.1323827786168565
#
# Alpha 0.07, Beta 0.24
# Mean Metric Value:  1.1292891222469517
#
# Alpha 0.07, Beta 0.25
# Mean Metric Value:  1.1265341097238697
#
# Alpha 0.07, Beta 0.26
# Mean Metric Value:  1.1242500997336515
#
# Alpha 0.07, Beta 0.27
# Mean Metric Value:  1.122537396180503
#
# Alpha 0.07, Beta 0.28
# Mean Metric Value:  1.1214635588617121
#
# Alpha 0.07, Beta 0.29
# Mean Metric Value:  1.1210635381034786
#
# Alpha 0.07, Beta 0.3
# Mean Metric Value:  1.1213408090114703
#
# Alpha 0.07, Beta 0.31
# Mean Metric Value:  1.1222697777564292
#
# Alpha 0.07, Beta 0.32
# Mean Metric Value:  1.1237995668451992
#
# Alpha 0.07, Beta 0.33
# Mean Metric Value:  1.1258590480992445
#
# Alpha 0.07, Beta 0.34
# Mean Metric Value:  1.128362779342345
#
# Alpha 0.07, Beta 0.35000000000000003
# Mean Metric Value:  1.131217356540426
#
# Alpha 0.07, Beta 0.36
# Mean Metric Value:  1.134327638256673
#
# Alpha 0.07, Beta 0.37
# Mean Metric Value:  1.137602339905606
#
# Alpha 0.07, Beta 0.38
# Mean Metric Value:  1.1409586204541662
#
# Alpha 0.07, Beta 0.39
# Mean Metric Value:  1.144325465062165
#
# Alpha 0.07, Beta 0.4
# Mean Metric Value:  1.1476458601654065
#
# Alpha 0.07, Beta 0.41000000000000003
# Mean Metric Value:  1.1508779139409582
#
# Alpha 0.07, Beta 0.42
# Mean Metric Value:  1.1539951564979776
#
# Alpha 0.07, Beta 0.43
# Mean Metric Value:  1.1569862479771826
#
# Alpha 0.07, Beta 0.44
# Mean Metric Value:  1.159854248912573
#
# Alpha 0.07, Beta 0.45
# Mean Metric Value:  1.1626155098761182
#
# Alpha 0.07, Beta 0.46
# Mean Metric Value:  1.165298165220368
#
# Alpha 0.07, Beta 0.47000000000000003
# Mean Metric Value:  1.16794020035237
#
# Alpha 0.07, Beta 0.48
# Mean Metric Value:  1.1705871060522002
#
# Alpha 0.07, Beta 0.49
# Mean Metric Value:  1.1732892128709003
#
# Alpha 0.07, Beta 0.5
# Mean Metric Value:  1.1760988770457308
#
# Alpha 0.07, Beta 0.51
# Mean Metric Value:  1.179067734928628
#
# ...
#
# Alpha 0.97, Beta 0.6900000000000001
# Mean Metric Value:  0.764902409137631
#
# Alpha 0.97, Beta 0.7000000000000001
# Mean Metric Value:  0.7703308639796701
#
# Alpha 0.97, Beta 0.71
# Mean Metric Value:  0.7757950231301621
#
# Alpha 0.97, Beta 0.72
# Mean Metric Value:  0.7812956142147963
#
# Alpha 0.97, Beta 0.73
# Mean Metric Value:  0.7868333856882117
#
# Alpha 0.97, Beta 0.74
# Mean Metric Value:  0.7924091076768933
#
# Alpha 0.97, Beta 0.75
# Mean Metric Value:  0.7980235728271529
#
# Alpha 0.97, Beta 0.76
# Mean Metric Value:  0.8036775971606421
#
# Alpha 0.97, Beta 0.77
# Mean Metric Value:  0.8093720209399478
#
# Alpha 0.97, Beta 0.78
# Mean Metric Value:  0.8151077095469156
#
# Alpha 0.97, Beta 0.79
# Mean Metric Value:  0.8208855543764589
#
# Alpha 0.97, Beta 0.8
# Mean Metric Value:  0.8267064737486918
#
# Alpha 0.97, Beta 0.81
# Mean Metric Value:  0.8325714138423498
#
# Alpha 0.97, Beta 0.8200000000000001
# Mean Metric Value:  0.8384813496525331
#
# Alpha 0.97, Beta 0.8300000000000001
# Mean Metric Value:  0.8444372859759403
#
# Alpha 0.97, Beta 0.84
# Mean Metric Value:  0.8504402584268317
#
# Alpha 0.97, Beta 0.85
# Mean Metric Value:  0.8564913344871067
#
# Alpha 0.97, Beta 0.86
# Mean Metric Value:  0.8625916145939496
#
# Alpha 0.97, Beta 0.87
# Mean Metric Value:  0.8687422332686525
#
# Alpha 0.97, Beta 0.88
# Mean Metric Value:  0.8749443602903124
#
# Alpha 0.97, Beta 0.89
# Mean Metric Value:  0.8811992019182382
#
# Alpha 0.97, Beta 0.9
# Mean Metric Value:  0.8875080021670365
#
# Alpha 0.97, Beta 0.91
# Mean Metric Value:  0.8938720441384616
#
# Alpha 0.97, Beta 0.92
# Mean Metric Value:  0.9002926514142876
#
# Alpha 0.97, Beta 0.93
# Mean Metric Value:  0.9067711895145713
#
# Alpha 0.97, Beta 0.9400000000000001
# Mean Metric Value:  0.913309067425869
#
# Alpha 0.97, Beta 0.9500000000000001
# Mean Metric Value:  0.9199077392041066
#
# Alpha 0.97, Beta 0.96
# Mean Metric Value:  0.9265687056569916
#
# Alpha 0.97, Beta 0.97
# Mean Metric Value:  0.9332935161110412
#
# Alpha 0.97, Beta 0.98
# Mean Metric Value:  0.9400837702684779
#
# Alpha 0.97, Beta 0.99
# Mean Metric Value:  0.9469411201594866
#
# Alpha 0.98, Beta 0.0
# Mean Metric Value:  0.4475120970876879
#
# Alpha 0.98, Beta 0.01
# Mean Metric Value:  0.44799917244879356
#
# Alpha 0.98, Beta 0.02
# Mean Metric Value:  0.4525113854409369
#
# Alpha 0.98, Beta 0.03
# Mean Metric Value:  0.4569436451586459
#
# Alpha 0.98, Beta 0.04
# Mean Metric Value:  0.46132621613981395
#
# Alpha 0.98, Beta 0.05
# Mean Metric Value:  0.46568592061739583
#
# Alpha 0.98, Beta 0.06
# Mean Metric Value:  0.4700372836348998
#
# Alpha 0.98, Beta 0.07
# Mean Metric Value:  0.47438756512871927
#
# Alpha 0.98, Beta 0.08
# Mean Metric Value:  0.4787401646934451
#
# Alpha 0.98, Beta 0.09
# Mean Metric Value:  0.48309659408573563
#
# Alpha 0.98, Beta 0.1
# Mean Metric Value:  0.4874574995388049
#
# Alpha 0.98, Beta 0.11
# Mean Metric Value:  0.4918231621983099
#
# Alpha 0.98, Beta 0.12
# Mean Metric Value:  0.4961937376020291
#
# Alpha 0.98, Beta 0.13
# Mean Metric Value:  0.5005693686555794
#
# Alpha 0.98, Beta 0.14
# Mean Metric Value:  0.5049502370210476
#
# Alpha 0.98, Beta 0.15
# Mean Metric Value:  0.5093365839446827
#
# Alpha 0.98, Beta 0.16
# Mean Metric Value:  0.5137287156794006
#
# Alpha 0.98, Beta 0.17
# Mean Metric Value:  0.5181270011879434
#
# Alpha 0.98, Beta 0.18
# Mean Metric Value:  0.5225318661749543
#
# Alpha 0.98, Beta 0.19
# Mean Metric Value:  0.526943785634605
#
# Alpha 0.98, Beta 0.2
# Mean Metric Value:  0.5313632760977796
#
# Alpha 0.98, Beta 0.21
# Mean Metric Value:  0.5357908882008702
#
# Alpha 0.98, Beta 0.22
# Mean Metric Value:  0.540227199876849
#
# Alpha 0.98, Beta 0.23
# Mean Metric Value:  0.544672810286039
#
# Alpha 0.98, Beta 0.24
# Mean Metric Value:  0.5491283345025878
#
# Alpha 0.98, Beta 0.25
# Mean Metric Value:  0.5535943989202081
#
# Alpha 0.98, Beta 0.26
# Mean Metric Value:  0.5580716373171906
#
# Alpha 0.98, Beta 0.27
# Mean Metric Value:  0.5625606875136188
#
# Alpha 0.98, Beta 0.28
# Mean Metric Value:  0.5670621885553546
#
# Alpha 0.98, Beta 0.29
# Mean Metric Value:  0.5715767783650917
#
# Alpha 0.98, Beta 0.3
# Mean Metric Value:  0.576105091807821
#
# Alpha 0.98, Beta 0.31
# Mean Metric Value:  0.5806477591250168
#
# Alpha 0.98, Beta 0.32
# Mean Metric Value:  0.5852054046979723
#
# Alpha 0.98, Beta 0.33
# Mean Metric Value:  0.5897786461058497
#
# Alpha 0.98, Beta 0.34
# Mean Metric Value:  0.594368093448094
#
# Alpha 0.98, Beta 0.35000000000000003
# Mean Metric Value:  0.5989743489041229
#
# Alpha 0.98, Beta 0.36
# Mean Metric Value:  0.6035980065057602
#
# Alpha 0.98, Beta 0.37
# Mean Metric Value:  0.6082396520999589
#
# Alpha 0.98, Beta 0.38
# Mean Metric Value:  0.6128998634810737
#
# Alpha 0.98, Beta 0.39
# Mean Metric Value:  0.6175792106734507
#
# Alpha 0.98, Beta 0.4
# Mean Metric Value:  0.6222782563464447
#
# Alpha 0.98, Beta 0.41000000000000003
# Mean Metric Value:  0.6269975563452707
#
# Alpha 0.98, Beta 0.42
# Mean Metric Value:  0.6317376603222964
#
# Alpha 0.98, Beta 0.43
# Mean Metric Value:  0.6364991124546006
#
# Alpha 0.98, Beta 0.44
# Mean Metric Value:  0.6412824522347836
#
# Alpha 0.98, Beta 0.45
# Mean Metric Value:  0.6460882153231622
#
# Alpha 0.98, Beta 0.46
# Mean Metric Value:  0.6509169344505988
#
# Alpha 0.98, Beta 0.47000000000000003
# Mean Metric Value:  0.6557691403622924
#
# Alpha 0.98, Beta 0.48
# Mean Metric Value:  0.6606453627938895
#
# Alpha 0.98, Beta 0.49
# Mean Metric Value:  0.6655461314722617
#
# Alpha 0.98, Beta 0.5
# Mean Metric Value:  0.6704719771342152
#
# Alpha 0.98, Beta 0.51
# Mean Metric Value:  0.6754234325572868
#
# Alpha 0.98, Beta 0.52
# Mean Metric Value:  0.6804010335975667
#
# Alpha 0.98, Beta 0.53
# Mean Metric Value:  0.6854053202302688
#
# Alpha 0.98, Beta 0.54
# Mean Metric Value:  0.6904368375894429
#
# Alpha 0.98, Beta 0.55
# Mean Metric Value:  0.6954961370038697
#
# Alpha 0.98, Beta 0.56
# Mean Metric Value:  0.7005837770267671
#
# Alpha 0.98, Beta 0.5700000000000001
# Mean Metric Value:  0.7057003244574614
#
# Alpha 0.98, Beta 0.58
# Mean Metric Value:  0.7108463553536709
#
# Alpha 0.98, Beta 0.59
# Mean Metric Value:  0.7160224560334871
#
# Alpha 0.98, Beta 0.6
# Mean Metric Value:  0.7212292240665444
#
# Alpha 0.98, Beta 0.61
# Mean Metric Value:  0.7264672692542309
#
# Alpha 0.98, Beta 0.62
# Mean Metric Value:  0.7317372145991272
#
# Alpha 0.98, Beta 0.63
# Mean Metric Value:  0.7370396972641605
#
# Alpha 0.98, Beta 0.64
# Mean Metric Value:  0.7423753695222358
#
# Alpha 0.98, Beta 0.65
# Mean Metric Value:  0.7477448996973537
#
# Alpha 0.98, Beta 0.66
# Mean Metric Value:  0.7531489730984571
#
# Alpha 0.98, Beta 0.67
# Mean Metric Value:  0.7585882929474533
#
# Alpha 0.98, Beta 0.68
# Mean Metric Value:  0.764063581303051
#
# Alpha 0.98, Beta 0.6900000000000001
# Mean Metric Value:  0.7695755799822308
#
# Alpha 0.98, Beta 0.7000000000000001
# Mean Metric Value:  0.7751250514813315
#
# Alpha 0.98, Beta 0.71
# Mean Metric Value:  0.7807127798988864
#
# Alpha 0.98, Beta 0.72
# Mean Metric Value:  0.7863395718624885
#
# Alpha 0.98, Beta 0.73
# Mean Metric Value:  0.7920062574621035
#
# Alpha 0.98, Beta 0.74
# Mean Metric Value:  0.797713691192374
#
# Alpha 0.98, Beta 0.75
# Mean Metric Value:  0.8034627529065893
#
# Alpha 0.98, Beta 0.76
# Mean Metric Value:  0.8092543487851117
#
# Alpha 0.98, Beta 0.77
# Mean Metric Value:  0.8150894123211742
#
# Alpha 0.98, Beta 0.78
# Mean Metric Value:  0.8209689053270809
#
# Alpha 0.98, Beta 0.79
# Mean Metric Value:  0.8268938189639539
#
# Alpha 0.98, Beta 0.8
# Mean Metric Value:  0.8328651747982955
#
# Alpha 0.98, Beta 0.81
# Mean Metric Value:  0.8388840258887513
#
# Alpha 0.98, Beta 0.8200000000000001
# Mean Metric Value:  0.8449514579065716
#
# Alpha 0.98, Beta 0.8300000000000001
# Mean Metric Value:  0.8510685902934123
#
# Alpha 0.98, Beta 0.84
# Mean Metric Value:  0.8572365774602193
#
# Alpha 0.98, Beta 0.85
# Mean Metric Value:  0.8634566100310933
#
# Alpha 0.98, Beta 0.86
# Mean Metric Value:  0.8697299161361525
#
# Alpha 0.98, Beta 0.87
# Mean Metric Value:  0.8760577627575625
#
# Alpha 0.98, Beta 0.88
# Mean Metric Value:  0.8824414571330501
#
# Alpha 0.98, Beta 0.89
# Mean Metric Value:  0.8888823482213629
#
# Alpha 0.98, Beta 0.9
# Mean Metric Value:  0.8953818282343146
#
# Alpha 0.98, Beta 0.91
# Mean Metric Value:  0.9019413342402159
#
# Alpha 0.98, Beta 0.92
# Mean Metric Value:  0.9085623498436787
#
# Alpha 0.98, Beta 0.93
# Mean Metric Value:  0.9152464069469664
#
# Alpha 0.98, Beta 0.9400000000000001
# Mean Metric Value:  0.9219950875982725
#
# Alpha 0.98, Beta 0.9500000000000001
# Mean Metric Value:  0.9288100259325253
#
# Alpha 0.98, Beta 0.96
# Mean Metric Value:  0.9356929102105386
#
# Alpha 0.98, Beta 0.97
# Mean Metric Value:  0.9426454849625906
#
# Alpha 0.98, Beta 0.98
# Mean Metric Value:  0.9496695532427533
#
# Alpha 0.98, Beta 0.99
# Mean Metric Value:  0.9567669790006098
#
# Alpha 0.99, Beta 0.0
# Mean Metric Value:  0.4473386090964484
#
# Alpha 0.99, Beta 0.01
# Mean Metric Value:  0.44792377190588756
#
# Alpha 0.99, Beta 0.02
# Mean Metric Value:  0.4524831363871211
#
# Alpha 0.99, Beta 0.03
# Mean Metric Value:  0.4569605273986158
#
# Alpha 0.99, Beta 0.04
# Mean Metric Value:  0.4613875958423585
#
# Alpha 0.99, Beta 0.05
# Mean Metric Value:  0.4657915448943161
#
# Alpha 0.99, Beta 0.06
# Mean Metric Value:  0.47018711225826426
#
# Alpha 0.99, Beta 0.07
# Mean Metric Value:  0.474581744294514
#
# Alpha 0.99, Beta 0.08
# Mean Metric Value:  0.47897900158535456
#
# Alpha 0.99, Beta 0.09
# Mean Metric Value:  0.4833805258370687
#
# Alpha 0.99, Beta 0.1
# Mean Metric Value:  0.48778706416626566
#
# Alpha 0.99, Beta 0.11
# Mean Metric Value:  0.4921989748162104
#
# Alpha 0.99, Beta 0.12
# Mean Metric Value:  0.49661647205721393
#
# Alpha 0.99, Beta 0.13
# Mean Metric Value:  0.5010397436580037
#
# Alpha 0.99, Beta 0.14
# Mean Metric Value:  0.5054690057502325
#
# Alpha 0.99, Beta 0.15
# Mean Metric Value:  0.5099045262982533
#
# Alpha 0.99, Beta 0.16
# Mean Metric Value:  0.5143466325359675
#
# Alpha 0.99, Beta 0.17
# Mean Metric Value:  0.5187957102171614
#
# Alpha 0.99, Beta 0.18
# Mean Metric Value:  0.5232521988420744
#
# Alpha 0.99, Beta 0.19
# Mean Metric Value:  0.5277165851283905
#
# Alpha 0.99, Beta 0.2
# Mean Metric Value:  0.5321893959708855
#
# Alpha 0.99, Beta 0.21
# Mean Metric Value:  0.5366711915581692
#
# Alpha 0.99, Beta 0.22
# Mean Metric Value:  0.5411625589840026
#
# Alpha 0.99, Beta 0.23
# Mean Metric Value:  0.5456641065001729
#
# Alpha 0.99, Beta 0.24
# Mean Metric Value:  0.5501764584506597
#
# Alpha 0.99, Beta 0.25
# Mean Metric Value:  0.5547002508694341
#
# Alpha 0.99, Beta 0.26
# Mean Metric Value:  0.5592361276965438
#
# Alpha 0.99, Beta 0.27
# Mean Metric Value:  0.563784737556556
#
# Alpha 0.99, Beta 0.28
# Mean Metric Value:  0.5683467310422435
#
# Alpha 0.99, Beta 0.29
# Mean Metric Value:  0.5729227584498422
#
# Alpha 0.99, Beta 0.3
# Mean Metric Value:  0.5775134679175083
#
# Alpha 0.99, Beta 0.31
# Mean Metric Value:  0.582119503924236
#
# Alpha 0.99, Beta 0.32
# Mean Metric Value:  0.5867415061116623
#
# Alpha 0.99, Beta 0.33
# Mean Metric Value:  0.5913801083956329
#
# Alpha 0.99, Beta 0.34
# Mean Metric Value:  0.5960359383380454
#
# Alpha 0.99, Beta 0.35000000000000003
# Mean Metric Value:  0.6007096167524392
#
# Alpha 0.99, Beta 0.36
# Mean Metric Value:  0.6054017575191977
#
# Alpha 0.99, Beta 0.37
# Mean Metric Value:  0.6101129675881866
#
# Alpha 0.99, Beta 0.38
# Mean Metric Value:  0.6148438471483486
#
# Alpha 0.99, Beta 0.39
# Mean Metric Value:  0.6195949899452428
#
# Alpha 0.99, Beta 0.4
# Mean Metric Value:  0.624366983728887
#
# Alpha 0.99, Beta 0.41000000000000003
# Mean Metric Value:  0.629160410815548
#
# Alpha 0.99, Beta 0.42
# Mean Metric Value:  0.6339758487483604
#
# Alpha 0.99, Beta 0.43
# Mean Metric Value:  0.6388138710428684
#
# Alpha 0.99, Beta 0.44
# Mean Metric Value:  0.643675048004763
#
# Alpha 0.99, Beta 0.45
# Mean Metric Value:  0.6485599476082382
#
# Alpha 0.99, Beta 0.46
# Mean Metric Value:  0.6534691364245077
#
# Alpha 0.99, Beta 0.47000000000000003
# Mean Metric Value:  0.6584031805911006
#
# Alpha 0.99, Beta 0.48
# Mean Metric Value:  0.663362646813582
#
# Alpha 0.99, Beta 0.49
# Mean Metric Value:  0.6683481033923222
#
# Alpha 0.99, Beta 0.5
# Mean Metric Value:  0.6733601212678697
#
# Alpha 0.99, Beta 0.51
# Mean Metric Value:  0.6783992750793276
#
# Alpha 0.99, Beta 0.52
# Mean Metric Value:  0.6834661442309657
#
# Alpha 0.99, Beta 0.53
# Mean Metric Value:  0.6885613139630192
#
# Alpha 0.99, Beta 0.54
# Mean Metric Value:  0.69368537642334
#
# Alpha 0.99, Beta 0.55
# Mean Metric Value:  0.6988389317371807
#
# Alpha 0.99, Beta 0.56
# Mean Metric Value:  0.7040225890729853
#
# Alpha 0.99, Beta 0.5700000000000001
# Mean Metric Value:  0.7092369677025885
#
# Alpha 0.99, Beta 0.58
# Mean Metric Value:  0.7144826980547071
#
# Alpha 0.99, Beta 0.59
# Mean Metric Value:  0.7197604227610623
#
# Alpha 0.99, Beta 0.6
# Mean Metric Value:  0.7250707976948578
#
# Alpha 0.99, Beta 0.61
# Mean Metric Value:  0.7304144930017265
#
# Alpha 0.99, Beta 0.62
# Mean Metric Value:  0.7357921941235731
#
# Alpha 0.99, Beta 0.63
# Mean Metric Value:  0.7412046028160703
#
# Alpha 0.99, Beta 0.64
# Mean Metric Value:  0.7466524381608223
#
# Alpha 0.99, Beta 0.65
# Mean Metric Value:  0.7521364375734844
#
# Alpha 0.99, Beta 0.66
# Mean Metric Value:  0.757657357809354
#
# Alpha 0.99, Beta 0.67
# Mean Metric Value:  0.7632159759681699
#
# Alpha 0.99, Beta 0.68
# Mean Metric Value:  0.7688130905000582
#
# Alpha 0.99, Beta 0.6900000000000001
# Mean Metric Value:  0.7744495222147464
#
# Alpha 0.99, Beta 0.7000000000000001
# Mean Metric Value:  0.7801261152963573
#
# Alpha 0.99, Beta 0.71
# Mean Metric Value:  0.7858437383262392
#
# Alpha 0.99, Beta 0.72
# Mean Metric Value:  0.7916032853164676
#
# Alpha 0.99, Beta 0.73
# Mean Metric Value:  0.7974056767567959
#
# Alpha 0.99, Beta 0.74
# Mean Metric Value:  0.8032518606779702
#
# Alpha 0.99, Beta 0.75
# Mean Metric Value:  0.809142813734489
#
# Alpha 0.99, Beta 0.76
# Mean Metric Value:  0.815079542309997
#
# Alpha 0.99, Beta 0.77
# Mean Metric Value:  0.8210630836486725
#
# Alpha 0.99, Beta 0.78
# Mean Metric Value:  0.8270945070160801
#
# Alpha 0.99, Beta 0.79
# Mean Metric Value:  0.833174914893111
#
# Alpha 0.99, Beta 0.8
# Mean Metric Value:  0.8393054442067787
#
# Alpha 0.99, Beta 0.81
# Mean Metric Value:  0.8454872676017645
#
# Alpha 0.99, Beta 0.8200000000000001
# Mean Metric Value:  0.8517215947567739
#
# Alpha 0.99, Beta 0.8300000000000001
# Mean Metric Value:  0.8580096737498994
#
# Alpha 0.99, Beta 0.84
# Mean Metric Value:  0.8643527924773518
#
# Alpha 0.99, Beta 0.85
# Mean Metric Value:  0.8707522801300847
#
# Alpha 0.99, Beta 0.86
# Mean Metric Value:  0.8772095087330052
#
# Alpha 0.99, Beta 0.87
# Mean Metric Value:  0.8837258947516355
#
# Alpha 0.99, Beta 0.88
# Mean Metric Value:  0.8903029007712957
#
# Alpha 0.99, Beta 0.89
# Mean Metric Value:  0.896942037254063
#
# Alpha 0.99, Beta 0.9
# Mean Metric Value:  0.9036448643789695
#
# Alpha 0.99, Beta 0.91
# Mean Metric Value:  0.9104129939711358
#
# Alpha 0.99, Beta 0.92
# Mean Metric Value:  0.9172480915257696
#
# Alpha 0.99, Beta 0.93
# Mean Metric Value:  0.9241518783332057
#
# Alpha 0.99, Beta 0.9400000000000001
# Mean Metric Value:  0.9311261337114396
#
# Alpha 0.99, Beta 0.9500000000000001
# Mean Metric Value:  0.9381726973529076
#
# Alpha 0.99, Beta 0.96
# Mean Metric Value:  0.9452934717925588
#
# Alpha 0.99, Beta 0.97
# Mean Metric Value:  0.952490425004616
#
# Alpha 0.99, Beta 0.98
# Mean Metric Value:  0.9597655931357942
#
# Alpha 0.99, Beta 0.99
# Mean Metric Value:  0.9671210833831242
#
# Alpha 			 Beta 			 Metric
# 0.0 			 0.08 			 49.38339575671946
# 0.0 			 0.23 			 49.38339575671946
# 0.0 			 0.13 			 49.38339575671846
# 0.0 			 0.19 			 49.38339575671846
# 0.0 			 0.28 			 49.38339575671846
#
# Time taken for Cross Validation: 590.5730571746826
# Alpha:  0.0 	 Beta:  0.08
# Fitting...
# Predicting...
# Accuracy:  0.4785100286532951
# Matthews Correlation Coefficient:  0.0
# Cohen Kappa Score:  0.0
# Confustion Matrix
# [[  0 546]
#  [  0 501]]
# Classification Report
#              precision    recall  f1-score   support
#
#          -1       0.00      0.00      0.00       546
#           1       0.48      1.00      0.65       501
#
# avg / total       0.23      0.48      0.31      1047
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
