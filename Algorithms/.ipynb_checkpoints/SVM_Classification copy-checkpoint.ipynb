# %%
import nbimporter
import helper_methods as hm
import preprocessing as pp
import numpy as np
import time
from sklearn import svm
from sklearn.metrics import accuracy_score, matthews_corrcoef
import matplotlib.pyplot as plt
import cvxopt
# Out:
# Importing Jupyter notebook from helper_methods.ipynb
# Importing Jupyter notebook from preprocessing.ipynb

# %% [markdown]
# ### SVM Classifier Implementation
# 16384
# .125

# %%
def linear_kernel(x1, x2):
    return np.dot(x1, x2)

def polynomial_kernel(x, y, p=3):
    return (1 + np.dot(x, y)) ** p

def gaussian_kernel(x, y, sigma=5.0):
    return np.exp(-linalg.norm(x-y)**2 / (2 * (sigma ** 2)))

# %%
class SVM(object):

    def __init__(self, kernel=linear_kernel, C=None):
        self.kernel = kernel
        self.C = C
        if self.C is not None: self.C = float(self.C)

    def fit(self, X, y):
        n_samples, n_features = X.shape

        # Gram matrix
        K = np.zeros((n_samples, n_samples))
        for i in range(n_samples):
            for j in range(n_samples):
                K[i,j] = self.kernel(X[i], X[j])

        P = cvxopt.matrix(np.outer(y,y) * K)
        q = cvxopt.matrix(np.ones(n_samples) * -1)
        A = cvxopt.matrix(y, (1,n_samples))
        b = cvxopt.matrix(0.0)

        if self.C is None:
            G = cvxopt.matrix(np.diag(np.ones(n_samples) * -1))
            h = cvxopt.matrix(np.zeros(n_samples))
        else:
            tmp1 = np.diag(np.ones(n_samples) * -1)
            tmp2 = np.identity(n_samples)
            G = cvxopt.matrix(np.vstack((tmp1, tmp2)))
            tmp1 = np.zeros(n_samples)
            tmp2 = np.ones(n_samples) * self.C
            h = cvxopt.matrix(np.hstack((tmp1, tmp2)))

        # solve QP problem
        solution = cvxopt.solvers.qp(P, q, G, h, A, b)

        # Lagrange multipliers
        a = np.ravel(solution['x'])

        # Support vectors have non zero lagrange multipliers
        sv = a > 1e-5
        ind = np.arange(len(a))[sv]
        self.a = a[sv]
        self.sv = X[sv]
        self.sv_y = y[sv]
        print("%d support vectors out of %d points" % (len(self.a), n_samples))

        # Intercept
        self.b = 0
        for n in range(len(self.a)):
            self.b += self.sv_y[n]
            self.b -= np.sum(self.a * self.sv_y * K[ind[n],sv])
        self.b /= len(self.a)

        # Weight vector
        if self.kernel == linear_kernel:
            self.w = np.zeros(n_features)
            for n in range(len(self.a)):
                self.w += self.a[n] * self.sv_y[n] * self.sv[n]
        else:
            self.w = None

    def project(self, X):
        if self.w is not None:
            return np.dot(X, self.w) + self.b
        else:
            y_predict = np.zeros(len(X))
            for i in range(len(X)):
                s = 0
                for a, sv_y, sv in zip(self.a, self.sv_y, self.sv):
                    s += a * sv_y * self.kernel(X[i], sv)
                y_predict[i] = s
            return y_predict + self.b

    def predict(self, X):
        return np.sign(self.project(X))

# %% [markdown]
# ### Finding Optimal Parameters
# https://stats.stackexchange.com/questions/43943/which-search-range-for-determining-svm-optimal-c-and-gamma-parameters

# %%
def print_parameters_accuracy(accuracies):
    print('#Features \t C \t Gamma \t Accuracy')
    for i in range(len(accuracies)):
        print(accuracies[i][0], '\t\t', accuracies[i][1], '\t\t', accuracies[i][2], '\t\t', accuracies[i][3])
    print()

# %%
def find_optimal_values(max_features, kernel = 'rbf', num_splits = 10, symbol_name = 'AAPL', use_implementation = True):
    accuracies = list()
    for num_features in range(1, max_features + 1, 1):
        print('Features:', num_features)
        
        X_train, X_test, Y_train, Y_test = hm.prepare_data(num_features, symbol_name, is_binary_ouput=True)
        X_train, X_test, Y_train, Y_test = X_train.values, X_test.values, Y_train.values, Y_test.values
        
#         for C in [1, 10, 100, 500, 1000, 5000, 10000]:
        for C in [2 ** x for x in range(-5, 15)]:
#             for gamma in [1, 0.1, 0.05, 0.01, 0.005, 0.001]:
            for gamma in [2 ** x for x in range(-15, 3)]:
                print('(C, gamma) ------------------------> (' + str(C) + ', ' + str(gamma) + ')')
                skl_svm_tscv = svm.SVC(kernel=kernel, C=C, gamma=gamma)
                if use_implementation:
                    accuracy = hm.timeSeriesCV(X_train, Y_train, num_splits, skl_svm_tscv, is_classification=True)
                else:
                    accuracy = hm.rolling_cross_validation(X_train, Y_train, num_splits, skl_svm_tscv, is_classification=True)
                accuracies.append([num_features, C, gamma, accuracy])
    
    print_parameters_accuracy(accuracies)
    
    # Sorting the accuracies
    accuracies.sort(reverse=True, key=lambda x: x[len(accuracies) - 1])
    print_parameters_accuracy(accuracies)
    
    return accuracies[0][0], accuracies[0][1], accuracies[0][2]

# %%
def get_data_ready(symbol_name):
    num_features, C, gamma = find_optimal_values(max_features=15, kernel = 'rbf', num_splits=10, symbol_name = symbol_name)
    
    X_train, X_test, Y_train, Y_test = hm.prepare_data(num_features)
    X_train, X_test, Y_train, Y_test = X_train.values, X_test.values, Y_train.values, Y_test.values
    return X_train, X_test, Y_train, Y_test, C, gamma

# %% [markdown]
# ### 1. SkLearn SVM Classifier

# %%
def sklearn_SVM_forecast(X_train, X_test, Y_train, Y_test, gamma, C = 1.0, kernel = 'rbf'):
    print('SKLEARN INBUILT SVM')
    clf = svm.SVC(kernel = kernel, C = C, gamma=gamma)
    clf.fit(X_train, Y_train)
    print('In-Built SVM (Accuracy) score -- kernel =', kernel, '--', clf.score(X_test, Y_test), '\n')

# %% [markdown]
# ### 2. Predicting using Implementation

# %% [markdown]
# ### Running SVM

# %%
def forecast(X_train, X_test, Y_train, Y_test, gamma, C = 1.0):
    print('C:', C, '\t gamma:', gamma)
    sklearn_SVM_forecast(X_train, X_test, Y_train, Y_test, gamma, C, kernel = 'rbf')
    
# X_train, X_test, Y_train, Y_test = hm.prepare_data(2)
# X_train, X_test, Y_train, Y_test = X_train.values, X_test.values, Y_train.values, Y_test.values
# forecast(X_train, X_test, Y_train, Y_test, 'rbf')

# %%
def run_SVM(symbol_name):
    X_train, X_test, Y_train, Y_test, C, gamma = get_data_ready(symbol_name)
    forecast(X_train, X_test, Y_train, Y_test, gamma, C)

# %%
run_SVM(symbol_name = 'INX')
# Out:
# Features: 1
# (C, gamma) ------------------------> (0.03125, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.03125, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.0625, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.125, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.25, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (0.5, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (32, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (32, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (32, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5034013605442177
#
# (C, gamma) ------------------------> (64, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (64, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (64, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (64, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (128, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (128, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (128, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (128, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (128, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5042517006802721
#
# (C, gamma) ------------------------> (256, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (256, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (256, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (256, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (256, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (512, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (512, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (512, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (512, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (512, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922903
#
# (C, gamma) ------------------------> (512, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (512, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (1024, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (1024, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (1024, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (1024, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (1024, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922903
#
# (C, gamma) ------------------------> (1024, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (1024, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5065192743764173
#
# (C, gamma) ------------------------> (1024, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.506235827664399
#
# (C, gamma) ------------------------> (2048, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (2048, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (2048, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (2048, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (2048, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922903
#
# (C, gamma) ------------------------> (2048, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# (C, gamma) ------------------------> (2048, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5065192743764172
#
# (C, gamma) ------------------------> (2048, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (2048, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.506235827664399
#
# (C, gamma) ------------------------> (4096, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (4096, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (4096, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (4096, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (4096, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5068027210884354
#
# (C, gamma) ------------------------> (4096, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5065192743764172
#
# (C, gamma) ------------------------> (4096, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5065192743764173
#
# (C, gamma) ------------------------> (4096, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (4096, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5065192743764172
#
# (C, gamma) ------------------------> (8192, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (8192, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (8192, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5053854875283448
#
# (C, gamma) ------------------------> (8192, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922903
#
# (C, gamma) ------------------------> (8192, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# (C, gamma) ------------------------> (8192, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5073696145124716
#
# (C, gamma) ------------------------> (8192, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5065192743764172
#
# (C, gamma) ------------------------> (8192, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (8192, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (8192, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (16384, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5048185941043084
#
# (C, gamma) ------------------------> (16384, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5051020408163266
#
# (C, gamma) ------------------------> (16384, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5031179138321995
#
# (C, gamma) ------------------------> (16384, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5068027210884354
#
# (C, gamma) ------------------------> (16384, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5045351473922903
#
# (C, gamma) ------------------------> (16384, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5068027210884354
#
# (C, gamma) ------------------------> (16384, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5073696145124716
#
# (C, gamma) ------------------------> (16384, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5068027210884354
#
# (C, gamma) ------------------------> (16384, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5053854875283447
#
# (C, gamma) ------------------------> (16384, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5053854875283447
#
# (C, gamma) ------------------------> (16384, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5053854875283447
#
# (C, gamma) ------------------------> (16384, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# Features: 2
# (C, gamma) ------------------------> (0.03125, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.502267573696145
#
# (C, gamma) ------------------------> (0.03125, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.502267573696145
#
# (C, gamma) ------------------------> (0.03125, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5025510204081632
#
# (C, gamma) ------------------------> (0.03125, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (0.03125, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# (C, gamma) ------------------------> (0.03125, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (0.03125, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 0.5)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 1)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 2)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.03125, 4)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 3.0517578125e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.502267573696145
#
# (C, gamma) ------------------------> (0.0625, 6.103515625e-05)
# Implemented Rolling Cross Validation
# Accuracy: 0.502267573696145
#
# (C, gamma) ------------------------> (0.0625, 0.0001220703125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5025510204081632
#
# (C, gamma) ------------------------> (0.0625, 0.000244140625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (0.0625, 0.00048828125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5070861678004536
#
# (C, gamma) ------------------------> (0.0625, 0.0009765625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.001953125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5059523809523809
#
# (C, gamma) ------------------------> (0.0625, 0.00390625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.0078125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.015625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.03125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.0625)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.125)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
# (C, gamma) ------------------------> (0.0625, 0.25)
# Implemented Rolling Cross Validation
# Accuracy: 0.5062358276643991
#
